# %% [markdown]
# # Imports and General Settings

# %%
import os

import tensorflow as tf
import tensorflow.contrib as tf_contrib

import pathlib

import numpy as np

import random
from cleverhans.loss import SNNLCrossEntropy
from tensorflow.examples.tutorials.mnist import input_data

import model_arch_utility as model_arch

# which GPU to be used (0 is RTX, 1 or 2 are either of the Titan Xps)
gpu = "/GPU:0"

AUTOTUNE = tf.contrib.data.AUTOTUNE

tf.enable_eager_execution()

session_config = tf.ConfigProto()
session_config.gpu_options.allow_growth = True
session_config.allow_soft_placement = True

# session_config.log_device_placement = True
tf.keras.backend.set_session(tf.Session(config=session_config))

print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %% [markdown]
# # ResNet Utility Functions

# %%
# Xavier : tf_contrib.layers.xavier_initializer()
# He : tf_contrib.layers.variance_scaling_initializer()
# Normal : tf.random_normal_initializer(mean=0.0, stddev=0.02)
# l2_decay : tf_contrib.layers.l2_regularizer(0.0001)

weight_init = tf_contrib.layers.variance_scaling_initializer()
weight_regularizer = tf_contrib.layers.l2_regularizer(0.0001)


##################################################################################
# Layer
##################################################################################

def conv(x, channels, kernel=4, stride=2, padding='SAME', use_bias=True, scope='conv_0'):
    with tf.variable_scope(scope):
        x = tf.layers.conv2d(inputs=x, filters=channels,
                             kernel_size=kernel, kernel_initializer=weight_init,
                             kernel_regularizer=weight_regularizer,
                             strides=stride, use_bias=use_bias, padding=padding)

        return x

def fully_connected(x, units, use_bias=True, scope='fully_0'):
    with tf.variable_scope(scope):
        x = flatten(x)
        x = tf.layers.dense(x, units=units, kernel_initializer=weight_init, kernel_regularizer=weight_regularizer, use_bias=use_bias)

        return x

def resblock(x_init, channels, kernel=3, is_training=True, use_bias=True, downsample=False, scope='resblock') :
    with tf.variable_scope(scope) :

        x = batch_norm(x_init, is_training, scope='batch_norm_0')
        x = relu(x)

        if downsample :
            x = conv(x, channels, kernel=kernel, stride=2, use_bias=use_bias, scope='conv_0')
            x_init = conv(x_init, channels, kernel=1, stride=2, use_bias=use_bias, scope='conv_init')

        else :
            x = conv(x, channels, kernel=kernel, stride=1, use_bias=use_bias, scope='conv_0')

        x = batch_norm(x, is_training, scope='batch_norm_1')
        x = relu(x)
        x = conv(x, channels, kernel=kernel, stride=1, use_bias=use_bias, scope='conv_1')

        return x + x_init

def bottle_resblock(x_init, channels, is_training=True, use_bias=True, downsample=False, scope='bottle_resblock') :
    with tf.variable_scope(scope) :
        x = batch_norm(x_init, is_training, scope='batch_norm_1x1_front')
        shortcut = relu(x)

        x = conv(shortcut, channels, kernel=1, stride=1, use_bias=use_bias, scope='conv_1x1_front')
        x = batch_norm(x, is_training, scope='batch_norm_3x3')
        x = relu(x)

        if downsample :
            x = conv(x, channels, kernel=3, stride=2, use_bias=use_bias, scope='conv_0')
            shortcut = conv(shortcut, channels*4, kernel=1, stride=2, use_bias=use_bias, scope='conv_init')

        else :
            x = conv(x, channels, kernel=3, stride=1, use_bias=use_bias, scope='conv_0')
            shortcut = conv(shortcut, channels * 4, kernel=1, stride=1, use_bias=use_bias, scope='conv_init')

        x = batch_norm(x, is_training, scope='batch_norm_1x1_back')
        x = relu(x)
        x = conv(x, channels*4, kernel=1, stride=1, use_bias=use_bias, scope='conv_1x1_back')

        return x + shortcut


##################################################################################
# Sampling
##################################################################################

def flatten(x) :
    return tf.layers.flatten(x)

def global_avg_pooling(x):
    gap = tf.reduce_mean(x, axis=[1, 2], keepdims=True)
    return gap

def avg_pooling(x) :
    return tf.layers.average_pooling2d(x, pool_size=2, strides=2, padding='SAME')

def max_pooling(x) :
    return tf.layers.max_pooling2d(x, pool_size=2, strides=2, padding='SAME')


##################################################################################
# Activation function
##################################################################################

def relu(x):
    return tf.nn.relu(x)


##################################################################################
# Normalization function
##################################################################################

def batch_norm(x, is_training=True, scope='batch_norm'):
    return tf_contrib.layers.batch_norm(x,
                                        decay=0.9, epsilon=1e-05,
                                        center=True, scale=True, updates_collections=None,
                                        is_training=is_training, scope=scope)

##################################################################################
# Loss function
##################################################################################

def classification_loss(logit, label) :
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=label, logits=logit))
    prediction = tf.equal(tf.argmax(logit, -1), tf.argmax(label, -1))
    accuracy = tf.reduce_mean(tf.cast(prediction, tf.float32))

    return loss, accuracy

# %% [markdown]
# # ResNet-10

# %% [markdown]
# ## Architecture

# %%
num_classes = 10

# ResNet-10 architecture
def resnet10_network(x, conv_kernel=7, resblock_kernel=3, num_channels=4, n_classes=num_classes, reuse = False, is_training = True):
    with tf.variable_scope('Resnet-10', reuse = reuse), tf.device(gpu):
        
        x = tf.reshape(x, shape=[-1, 28, 28, 1])
        # channels
        
        filtered_images = []
        
        filtered_images.append(tf.identity(x))
        
        x = model_arch.conv(x, num_channels, kernel=conv_kernel, stride=1, padding='SAME')
        
        filtered_images.append(tf.identity(x))
        
        x = model_arch.resblock(x, channels=num_channels, kernel=resblock_kernel, is_training=is_training, 
                      downsample=False, scope='resblock1_id1')      
   
        filtered_images.append(tf.identity(x))

        x = model_arch.resblock(x, channels=num_channels * 2, kernel=resblock_kernel, is_training=is_training, 
                     downsample=True, scope='resblock2_conv1')
        
        filtered_images.append(tf.identity(x))

        x = model_arch.resblock(x, channels=num_channels * 2, kernel=resblock_kernel, is_training=is_training, 
                      downsample=False, scope='resblock3_id2')
        
        filtered_images.append(tf.identity(x))
        
        x = model_arch.resblock(x, channels=num_channels * 4, kernel=resblock_kernel, is_training=is_training, 
                     downsample=True, scope='resblock4_conv2')

        filtered_images.append(tf.identity(x))
        
        x = model_arch.resblock(x, channels=num_channels * 4, kernel=resblock_kernel, is_training=is_training, 
                      downsample=False, scope='resblock5_id3')
        
        filtered_images.append(tf.identity(x))
        
        
        x = model_arch.batch_norm(x, is_training, scope='batch_norm')
        
        x = model_arch.relu(x)
        
        x_pre_flatten = tf.identity(x)
        
        x = model_arch.fully_connected(x, num_classes)
        
        return x, x_pre_flatten, filtered_images

    
def resnet10_model_fn(features, labels, mode, conv_kernel=7, resblock_kernel=3, num_channels=4, snnl_weight=0.05,
                      log=True):
    with tf.device(gpu):

        print("in gpu part")
        logits_train, activ_maps_train, filtered_images = resnet10_network(features,
                                                          conv_kernel=conv_kernel,
                                                          resblock_kernel=resblock_kernel,
                                                          num_channels=num_channels,
                                                          n_classes=num_classes,
                                                          reuse=False,
                                                          is_training=True)

        logits_test, activ_maps_test, _ = resnet10_network(features,
                                                        conv_kernel=conv_kernel,
                                                        resblock_kernel=resblock_kernel,
                                                        num_channels=num_channels,
                                                        n_classes=num_classes,
                                                        reuse=True,
                                                        is_training=False)

        pred_classes = tf.arg_max(logits_test, dimension=1)

        # PREDICT MODE
        if mode == tf.estimator.ModeKeys.PREDICT:

            return tf.estimator.EstimatorSpec(mode=mode, predictions=pred_classes)


        loss_op = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits_train, labels=tf.cast(labels, dtype=tf.int32)))

        loss_op = (1.0 - snnl_weight) * loss_op + snnl_weight * SNNLCrossEntropy.optimized_temp_SNNL(
            model_arch.flatten(activ_maps_train), labels, 20.0, True)
        
        acc_op = tf.metrics.accuracy(labels=labels, predictions=pred_classes)

        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss_op, global_step=tf.train.get_global_step())
        
        tf.summary.scalar("loss", loss_op)
        tf.summary.scalar("accuracy", acc_op[1])
        
        if mode == tf.estimator.ModeKeys.TRAIN:
                

            # the different ops for training, evaluating, ...
            estim_specs = tf.estimator.EstimatorSpec(
                mode=mode,
                predictions=pred_classes,
                loss=loss_op,
                train_op=train_op,
                eval_metric_ops={'accuracy': acc_op}
            )

            return estim_specs
    
#     for var in tf.trainable_variables():
#         print(var.name)

        if (log):

            conv0_weights = [v for v in tf.global_variables() if v.name == "Resnet-10/conv_0/conv2d/kernel:0"][0]

            plot_op_expanded = tf.expand_dims(log_util.plot_conv_weights(conv0_weights), 0)
            tf.summary.image("conv_0_weight_plots", plot_op_expanded)


            with tf.name_scope("activation_maps"):

                level_dict = {0 : "0_original_image",         
                              1 : "1_after_initial_conv",
                              2 : "2_after_resblock1_id1",
                              3 : "3_after_resblock2_conv1",
                              4 : "4_after_resblock3_id2",
                              5 : "5_after_resblock4_conv2",
                              6 : "6_after_resblock5_id3"}

                counter = 0

                plot_ops = []

                for filtered_im in filtered_images:

                    activation_map = tf.slice(filtered_im,[0, 0, 0, 0],[1, -1, -1, -1])
                    activation_op = tf.expand_dims(log_util.plot_conv_output(activation_map, level_dict[counter]), 0)

                    plot_ops.append(activation_op)

                    counter = counter + 1

                final_log_op = tf.concat(plot_ops, 1)

                tf.summary.image("image_display", final_log_op)
        
        eval_summary_hook = tf.train.SummarySaverHook(
            save_steps=1,
            output_dir=model_path + "/eval_images",
            summary_op=tf.summary.merge_all())
        # Add it to the evaluation_hook list
        evaluation_hooks = []
        evaluation_hooks.append(eval_summary_hook)

        # the different ops for training, evaluating, ...
        estim_specs = tf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss_op,
            train_op=train_op,
            eval_metric_ops={'accuracy': acc_op},
            evaluation_hooks=evaluation_hooks
        )

        return estim_specs

# %% [markdown]
# ## Experimentation

# %%
tf.logging.set_verbosity(tf.logging.INFO)

b_size = 64

learning_rate = 0.001

random_seed = 777

num_steps = 4000

tf.summary.FileWriterCache.clear()

model_path = model_dir="/tmp/resnet_mnist_snnl/with_snnl_loss/"
        
config = tf.estimator.RunConfig(
    log_step_count_steps= 20,
    save_summary_steps= 50,
    save_checkpoints_secs= 5,
    model_dir="/tmp/resnet_mnist_snnl/with_snnl_loss/",
    tf_random_seed=random_seed,
    session_config=session_config)

model_fn = lambda features, labels, mode: resnet10_model_fn(features, labels, mode, conv_kernel=7, num_channels=8, log=False)

mnist = input_data.read_data_sets("/tmp/data/", one_hot=False)

# Define the input function for training
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x=mnist.train.images, y=mnist.train.labels, batch_size=b_size, num_epochs=None, shuffle=True)

eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x=mnist.test.images, y=mnist.test.labels, batch_size=b_size, num_epochs=None, shuffle=True)



model = tf.estimator.Estimator(model_fn=model_fn, config=config)

train_spec = tf.estimator.TrainSpec(input_fn=train_input_fn, max_steps=num_steps)
eval_spec = tf.estimator.EvalSpec(input_fn=eval_input_fn, throttle_secs=5)

tf.estimator.train_and_evaluate(model, train_spec, eval_spec)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/resnet_mnist_snnl/with_snnl_loss/', '_tf_random_seed': 777, '_save_summary_steps': 50, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 5, '_session_config': gpu_options {
#   allow_growth: true
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 20, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3f706f1438>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 5.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:loss = 0.20601112, step = 200
# INFO:tensorflow:global_step/sec: 20.9979
# INFO:tensorflow:loss = 0.21740264, step = 220 (0.953 sec)
# INFO:tensorflow:global_step/sec: 89.8035
# INFO:tensorflow:loss = 0.2695535, step = 240 (0.223 sec)
# INFO:tensorflow:global_step/sec: 32.9734
# INFO:tensorflow:loss = 0.40663218, step = 260 (0.607 sec)
# INFO:tensorflow:global_step/sec: 86.9886
# INFO:tensorflow:loss = 0.20455939, step = 280 (0.230 sec)
# INFO:tensorflow:global_step/sec: 86.9195
# INFO:tensorflow:loss = 0.19151036, step = 300 (0.231 sec)
# INFO:tensorflow:global_step/sec: 90.0139
# INFO:tensorflow:loss = 0.31294456, step = 320 (0.222 sec)
# INFO:tensorflow:global_step/sec: 85.5606
# INFO:tensorflow:loss = 0.19540922, step = 340 (0.233 sec)
# INFO:tensorflow:global_step/sec: 88.6256
# INFO:tensorflow:loss = 0.26227474, step = 360 (0.226 sec)
# INFO:tensorflow:global_step/sec: 87.2885
# INFO:tensorflow:loss = 0.24866116, step = 380 (0.229 sec)
# INFO:tensorflow:global_step/sec: 89.587
# INFO:tensorflow:loss = 0.26361725, step = 400 (0.224 sec)
# INFO:tensorflow:global_step/sec: 85.2054
# INFO:tensorflow:loss = 0.18759397, step = 420 (0.234 sec)
# INFO:tensorflow:global_step/sec: 89.6946
# INFO:tensorflow:loss = 0.26345712, step = 440 (0.223 sec)
# INFO:tensorflow:global_step/sec: 86.2035
# INFO:tensorflow:loss = 0.2558766, step = 460 (0.232 sec)
# INFO:tensorflow:global_step/sec: 83.0424
# INFO:tensorflow:loss = 0.14841478, step = 480 (0.241 sec)
# INFO:tensorflow:global_step/sec: 84.993
# INFO:tensorflow:loss = 0.20273817, step = 500 (0.236 sec)
# INFO:tensorflow:Saving checkpoints for 503 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:34:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-503
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:34:07
# INFO:tensorflow:Saving dict for global step 503: accuracy = 0.97828126, global_step = 503, loss = 0.18310106
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 503: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-503
# INFO:tensorflow:global_step/sec: 4.44086
# INFO:tensorflow:loss = 0.19737874, step = 520 (4.504 sec)
# INFO:tensorflow:global_step/sec: 94.8667
# INFO:tensorflow:loss = 0.15577085, step = 540 (0.210 sec)
# INFO:tensorflow:global_step/sec: 85.9563
# INFO:tensorflow:loss = 0.25229675, step = 560 (0.233 sec)
# INFO:tensorflow:Saving checkpoints for 569 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (5 secs).
# INFO:tensorflow:global_step/sec: 48.474
# INFO:tensorflow:loss = 0.20841143, step = 580 (0.413 sec)
# INFO:tensorflow:global_step/sec: 82.1363
# INFO:tensorflow:loss = 0.28059202, step = 600 (0.244 sec)
# INFO:tensorflow:global_step/sec: 85.6615
# INFO:tensorflow:loss = 0.17083998, step = 620 (0.233 sec)
# INFO:tensorflow:global_step/sec: 87.0139
# INFO:tensorflow:loss = 0.20414348, step = 640 (0.230 sec)
# INFO:tensorflow:global_step/sec: 90.0201
# INFO:tensorflow:loss = 0.24757957, step = 660 (0.222 sec)
# INFO:tensorflow:global_step/sec: 92.3093
# INFO:tensorflow:loss = 0.14273529, step = 680 (0.217 sec)
# INFO:tensorflow:global_step/sec: 92.8659
# INFO:tensorflow:loss = 0.20929918, step = 700 (0.216 sec)
# INFO:tensorflow:global_step/sec: 85.7101
# INFO:tensorflow:loss = 0.14516465, step = 720 (0.232 sec)
# INFO:tensorflow:global_step/sec: 84.5193
# INFO:tensorflow:loss = 0.13989718, step = 740 (0.237 sec)
# INFO:tensorflow:global_step/sec: 87.313
# INFO:tensorflow:loss = 0.13552253, step = 760 (0.229 sec)
# INFO:tensorflow:global_step/sec: 90.2067
# INFO:tensorflow:loss = 0.15140113, step = 780 (0.222 sec)
# INFO:tensorflow:global_step/sec: 89.3069
# INFO:tensorflow:loss = 0.15657221, step = 800 (0.225 sec)
# INFO:tensorflow:global_step/sec: 83.5158
# INFO:tensorflow:loss = 0.1453379, step = 820 (0.238 sec)
# INFO:tensorflow:global_step/sec: 91.9458
# INFO:tensorflow:loss = 0.16458121, step = 840 (0.218 sec)
# INFO:tensorflow:global_step/sec: 91.2068
# INFO:tensorflow:loss = 0.16352586, step = 860 (0.219 sec)
# INFO:tensorflow:global_step/sec: 87.9777
# INFO:tensorflow:loss = 0.3006919, step = 880 (0.229 sec)
# INFO:tensorflow:global_step/sec: 82.5464
# INFO:tensorflow:loss = 0.17609537, step = 900 (0.242 sec)
# INFO:tensorflow:global_step/sec: 80.0706
# INFO:tensorflow:loss = 0.18155485, step = 920 (0.249 sec)
# INFO:tensorflow:global_step/sec: 81.7392
# INFO:tensorflow:loss = 0.26205817, step = 940 (0.244 sec)
# INFO:tensorflow:global_step/sec: 85.9418
# INFO:tensorflow:loss = 0.2516656, step = 960 (0.233 sec)
# INFO:tensorflow:global_step/sec: 84.3972
# INFO:tensorflow:loss = 0.20627914, step = 980 (0.237 sec)
# INFO:tensorflow:Saving checkpoints for 987 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:34:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-987
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:34:16
# INFO:tensorflow:Saving dict for global step 987: accuracy = 0.9840625, global_step = 987, loss = 0.16540614
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 987: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-987
# INFO:tensorflow:global_step/sec: 4.80545
# INFO:tensorflow:loss = 0.18630329, step = 1000 (4.163 sec)
# INFO:tensorflow:global_step/sec: 96.7357
# INFO:tensorflow:loss = 0.18923633, step = 1020 (0.205 sec)
# INFO:tensorflow:global_step/sec: 87.4895
# INFO:tensorflow:loss = 0.1563124, step = 1040 (0.229 sec)
# INFO:tensorflow:global_step/sec: 86.228
# INFO:tensorflow:loss = 0.14859918, step = 1060 (0.232 sec)
# INFO:tensorflow:Saving checkpoints for 1081 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (5 secs).
# INFO:tensorflow:global_step/sec: 47.4823
# INFO:tensorflow:loss = 0.1917437, step = 1080 (0.421 sec)
# INFO:tensorflow:global_step/sec: 86.3192
# INFO:tensorflow:loss = 0.12182822, step = 1100 (0.233 sec)
# INFO:tensorflow:global_step/sec: 97.764
# INFO:tensorflow:loss = 0.21292123, step = 1120 (0.203 sec)
# INFO:tensorflow:global_step/sec: 89.0568
# INFO:tensorflow:loss = 0.13479942, step = 1140 (0.225 sec)
# INFO:tensorflow:global_step/sec: 84.9582
# INFO:tensorflow:loss = 0.13621858, step = 1160 (0.235 sec)
# INFO:tensorflow:global_step/sec: 88.0138
# INFO:tensorflow:loss = 0.19582689, step = 1180 (0.227 sec)
# INFO:tensorflow:global_step/sec: 81.6054
# INFO:tensorflow:loss = 0.15574226, step = 1200 (0.246 sec)
# INFO:tensorflow:global_step/sec: 83.8003
# INFO:tensorflow:loss = 0.17479688, step = 1220 (0.238 sec)
# INFO:tensorflow:global_step/sec: 88.5931
# INFO:tensorflow:loss = 0.13017991, step = 1240 (0.226 sec)
# INFO:tensorflow:global_step/sec: 84.3642
# INFO:tensorflow:loss = 0.24569485, step = 1260 (0.237 sec)
# INFO:tensorflow:global_step/sec: 87.1031
# INFO:tensorflow:loss = 0.24178478, step = 1280 (0.230 sec)
# INFO:tensorflow:global_step/sec: 91.0538
# INFO:tensorflow:loss = 0.15977548, step = 1300 (0.221 sec)
# INFO:tensorflow:global_step/sec: 82.5942
# INFO:tensorflow:loss = 0.12801744, step = 1320 (0.241 sec)
# INFO:tensorflow:global_step/sec: 96.1933
# INFO:tensorflow:loss = 0.13627473, step = 1340 (0.208 sec)
# INFO:tensorflow:global_step/sec: 84.0243
# INFO:tensorflow:loss = 0.13386975, step = 1360 (0.239 sec)
# INFO:tensorflow:global_step/sec: 93.8211
# INFO:tensorflow:loss = 0.14923453, step = 1380 (0.212 sec)
# INFO:tensorflow:global_step/sec: 85.6917
# INFO:tensorflow:loss = 0.19138181, step = 1400 (0.234 sec)
# INFO:tensorflow:global_step/sec: 86.4692
# INFO:tensorflow:loss = 0.12773573, step = 1420 (0.230 sec)
# INFO:tensorflow:global_step/sec: 89.554
# INFO:tensorflow:loss = 0.16413525, step = 1440 (0.223 sec)
# INFO:tensorflow:global_step/sec: 87.9703
# INFO:tensorflow:loss = 0.13400528, step = 1460 (0.227 sec)
# INFO:tensorflow:global_step/sec: 88.5898
# INFO:tensorflow:loss = 0.15917568, step = 1480 (0.226 sec)
# INFO:tensorflow:global_step/sec: 87.6459
# INFO:tensorflow:loss = 0.1611589, step = 1500 (0.229 sec)
# INFO:tensorflow:Saving checkpoints for 1504 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:34:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-1504
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:34:26
# INFO:tensorflow:Saving dict for global step 1504: accuracy = 0.98015624, global_step = 1504, loss = 0.17597315
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1504: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-1504
# INFO:tensorflow:global_step/sec: 4.90337
# INFO:tensorflow:loss = 0.1654353, step = 1520 (4.079 sec)
# INFO:tensorflow:global_step/sec: 85.7217
# INFO:tensorflow:loss = 0.23253368, step = 1540 (0.232 sec)
# INFO:tensorflow:global_step/sec: 85.8999
# INFO:tensorflow:loss = 0.119944796, step = 1560 (0.233 sec)
# INFO:tensorflow:global_step/sec: 93.6099
# INFO:tensorflow:loss = 0.14307895, step = 1580 (0.213 sec)
# INFO:tensorflow:global_step/sec: 89.7508
# INFO:tensorflow:loss = 0.13480255, step = 1600 (0.223 sec)
# INFO:tensorflow:Saving checkpoints for 1606 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:34:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-1606
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:34:32
# INFO:tensorflow:Saving dict for global step 1606: accuracy = 0.9871875, global_step = 1606, loss = 0.15504743
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1606: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-1606
# INFO:tensorflow:global_step/sec: 4.66619
# INFO:tensorflow:loss = 0.12175286, step = 1620 (4.286 sec)
# INFO:tensorflow:global_step/sec: 90.5494
# INFO:tensorflow:loss = 0.17492872, step = 1640 (0.222 sec)
# INFO:tensorflow:global_step/sec: 87.5841
# INFO:tensorflow:loss = 0.1333873, step = 1660 (0.226 sec)
# INFO:tensorflow:global_step/sec: 90.1643
# INFO:tensorflow:loss = 0.18330461, step = 1680 (0.222 sec)
# INFO:tensorflow:Saving checkpoints for 1691 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:34:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-1691
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:34:36
# INFO:tensorflow:Saving dict for global step 1691: accuracy = 0.98625, global_step = 1691, loss = 0.15615326
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1691: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-1691
# INFO:tensorflow:global_step/sec: 5.41062
# INFO:tensorflow:loss = 0.14012344, step = 1700 (3.697 sec)
# INFO:tensorflow:global_step/sec: 86.5754
# INFO:tensorflow:loss = 0.19103482, step = 1720 (0.231 sec)
# INFO:tensorflow:global_step/sec: 81.4264
# INFO:tensorflow:loss = 0.1453911, step = 1740 (0.245 sec)
# INFO:tensorflow:global_step/sec: 84.6505
# INFO:tensorflow:loss = 0.12211273, step = 1760 (0.236 sec)
# INFO:tensorflow:global_step/sec: 87.581
# INFO:tensorflow:loss = 0.18723913, step = 1780 (0.228 sec)
# INFO:tensorflow:global_step/sec: 89.1242
# INFO:tensorflow:loss = 0.12814745, step = 1800 (0.225 sec)
# INFO:tensorflow:global_step/sec: 86.7071
# INFO:tensorflow:loss = 0.20942807, step = 1820 (0.230 sec)
# INFO:tensorflow:Saving checkpoints for 1823 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:34:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-1823
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:34:41
# INFO:tensorflow:Saving dict for global step 1823: accuracy = 0.985, global_step = 1823, loss = 0.16333663
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1823: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-1823
# INFO:tensorflow:global_step/sec: 4.81629
# INFO:tensorflow:loss = 0.12369032, step = 1840 (4.154 sec)
# INFO:tensorflow:global_step/sec: 85.8394
# INFO:tensorflow:loss = 0.12840009, step = 1860 (0.231 sec)
# INFO:tensorflow:global_step/sec: 92.1813
# INFO:tensorflow:loss = 0.15060347, step = 1880 (0.217 sec)
# INFO:tensorflow:global_step/sec: 91.2191
# INFO:tensorflow:loss = 0.14415473, step = 1900 (0.220 sec)
# INFO:tensorflow:Saving checkpoints for 1920 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (5 secs).
# INFO:tensorflow:global_step/sec: 47.783
# INFO:tensorflow:loss = 0.1282708, step = 1920 (0.418 sec)
# INFO:tensorflow:global_step/sec: 84.0544
# INFO:tensorflow:loss = 0.16776407, step = 1940 (0.238 sec)
# INFO:tensorflow:global_step/sec: 80.5909
# INFO:tensorflow:loss = 0.12626508, step = 1960 (0.248 sec)
# INFO:tensorflow:global_step/sec: 78.76
# INFO:tensorflow:loss = 0.13693488, step = 1980 (0.254 sec)
# INFO:tensorflow:global_step/sec: 94.1483
# INFO:tensorflow:loss = 0.1400036, step = 2000 (0.213 sec)
# INFO:tensorflow:global_step/sec: 84.1457
# INFO:tensorflow:loss = 0.14381929, step = 2020 (0.237 sec)
# INFO:tensorflow:global_step/sec: 84.6418
# INFO:tensorflow:loss = 0.13841155, step = 2040 (0.236 sec)
# INFO:tensorflow:global_step/sec: 92.2156
# INFO:tensorflow:loss = 0.1325411, step = 2060 (0.217 sec)
# INFO:tensorflow:global_step/sec: 84.0202
# INFO:tensorflow:loss = 0.16810873, step = 2080 (0.238 sec)
# INFO:tensorflow:global_step/sec: 81.2248
# INFO:tensorflow:loss = 0.15293632, step = 2100 (0.247 sec)
# INFO:tensorflow:global_step/sec: 84.7486
# INFO:tensorflow:loss = 0.12852441, step = 2120 (0.235 sec)
# INFO:tensorflow:global_step/sec: 80.4473
# INFO:tensorflow:loss = 0.12855513, step = 2140 (0.248 sec)
# INFO:tensorflow:global_step/sec: 88.3551
# INFO:tensorflow:loss = 0.13431293, step = 2160 (0.226 sec)
# INFO:tensorflow:global_step/sec: 86.6671
# INFO:tensorflow:loss = 0.1348646, step = 2180 (0.231 sec)
# INFO:tensorflow:global_step/sec: 83.0195
# INFO:tensorflow:loss = 0.1311227, step = 2200 (0.244 sec)
# INFO:tensorflow:global_step/sec: 85.4061
# INFO:tensorflow:loss = 0.12100279, step = 2220 (0.232 sec)
# INFO:tensorflow:global_step/sec: 90.6344
# INFO:tensorflow:loss = 0.14230531, step = 2240 (0.220 sec)
# INFO:tensorflow:global_step/sec: 82.0965
# INFO:tensorflow:loss = 0.1288372, step = 2260 (0.244 sec)
# INFO:tensorflow:global_step/sec: 86.6128
# INFO:tensorflow:loss = 0.12968677, step = 2280 (0.231 sec)
# INFO:tensorflow:global_step/sec: 86.2283
# INFO:tensorflow:loss = 0.14347325, step = 2300 (0.233 sec)
# INFO:tensorflow:global_step/sec: 88.8882
# INFO:tensorflow:loss = 0.22566909, step = 2320 (0.224 sec)
# INFO:tensorflow:Saving checkpoints for 2329 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:34:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-2329
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:34:51
# INFO:tensorflow:Saving dict for global step 2329: accuracy = 0.9859375, global_step = 2329, loss = 0.16170582
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2329: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-2329
# INFO:tensorflow:global_step/sec: 4.90239
# INFO:tensorflow:loss = 0.13382238, step = 2340 (4.079 sec)
# INFO:tensorflow:global_step/sec: 84.6533
# INFO:tensorflow:loss = 0.12157917, step = 2360 (0.236 sec)
# INFO:tensorflow:global_step/sec: 85.6644
# INFO:tensorflow:loss = 0.12555842, step = 2380 (0.234 sec)
# INFO:tensorflow:global_step/sec: 86.6042
# INFO:tensorflow:loss = 0.12840374, step = 2400 (0.232 sec)
# INFO:tensorflow:global_step/sec: 81.8596
# INFO:tensorflow:loss = 0.1377044, step = 2420 (0.244 sec)
# INFO:tensorflow:Saving checkpoints for 2428 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (5 secs).
# INFO:tensorflow:global_step/sec: 46.7502
# INFO:tensorflow:loss = 0.12533817, step = 2440 (0.428 sec)
# INFO:tensorflow:global_step/sec: 85.7531
# INFO:tensorflow:loss = 0.12934507, step = 2460 (0.233 sec)
# INFO:tensorflow:global_step/sec: 88.0404
# INFO:tensorflow:loss = 0.22249243, step = 2480 (0.227 sec)
# INFO:tensorflow:global_step/sec: 84.6056
# INFO:tensorflow:loss = 0.1318148, step = 2500 (0.240 sec)
# INFO:tensorflow:global_step/sec: 84.417
# INFO:tensorflow:loss = 0.13853164, step = 2520 (0.233 sec)
# INFO:tensorflow:global_step/sec: 86.6067
# INFO:tensorflow:loss = 0.12191691, step = 2540 (0.231 sec)
# INFO:tensorflow:global_step/sec: 84.6921
# INFO:tensorflow:loss = 0.1429545, step = 2560 (0.236 sec)
# INFO:tensorflow:global_step/sec: 90.6003
# INFO:tensorflow:loss = 0.12631027, step = 2580 (0.221 sec)
# INFO:tensorflow:global_step/sec: 82.4789
# INFO:tensorflow:loss = 0.11999325, step = 2600 (0.244 sec)
# INFO:tensorflow:global_step/sec: 85.7453
# INFO:tensorflow:loss = 0.12187213, step = 2620 (0.232 sec)
# INFO:tensorflow:global_step/sec: 81.1448
# INFO:tensorflow:loss = 0.14014739, step = 2640 (0.246 sec)
# INFO:tensorflow:global_step/sec: 88.718
# INFO:tensorflow:loss = 0.1313965, step = 2660 (0.225 sec)
# INFO:tensorflow:global_step/sec: 95.0693
# INFO:tensorflow:loss = 0.1277702, step = 2680 (0.210 sec)
# INFO:tensorflow:global_step/sec: 86.2788
# INFO:tensorflow:loss = 0.13570428, step = 2700 (0.232 sec)
# INFO:tensorflow:global_step/sec: 93.9824
# INFO:tensorflow:loss = 0.119375385, step = 2720 (0.213 sec)
# INFO:tensorflow:global_step/sec: 85.0047
# INFO:tensorflow:loss = 0.12122502, step = 2740 (0.235 sec)
# INFO:tensorflow:global_step/sec: 89.7044
# INFO:tensorflow:loss = 0.11758209, step = 2760 (0.223 sec)
# INFO:tensorflow:global_step/sec: 89.2628
# INFO:tensorflow:loss = 0.13098077, step = 2780 (0.224 sec)
# INFO:tensorflow:global_step/sec: 85.2492
# INFO:tensorflow:loss = 0.16681078, step = 2800 (0.236 sec)
# INFO:tensorflow:global_step/sec: 88.5495
# INFO:tensorflow:loss = 0.12190639, step = 2820 (0.225 sec)
# INFO:tensorflow:global_step/sec: 86.0259
# INFO:tensorflow:loss = 0.18622243, step = 2840 (0.232 sec)
# INFO:tensorflow:Saving checkpoints for 2846 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:34:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-2846
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:35:02
# INFO:tensorflow:Saving dict for global step 2846: accuracy = 0.9865625, global_step = 2846, loss = 0.15981807
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2846: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-2846
# INFO:tensorflow:global_step/sec: 4.76025
# INFO:tensorflow:loss = 0.11996896, step = 2860 (4.202 sec)
# INFO:tensorflow:global_step/sec: 85.6466
# INFO:tensorflow:loss = 0.12579493, step = 2880 (0.233 sec)
# INFO:tensorflow:global_step/sec: 84.3475
# INFO:tensorflow:loss = 0.12784326, step = 2900 (0.238 sec)
# INFO:tensorflow:global_step/sec: 84.9856
# INFO:tensorflow:loss = 0.117492534, step = 2920 (0.234 sec)
# INFO:tensorflow:Saving checkpoints for 2934 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:35:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-2934
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:35:06
# INFO:tensorflow:Saving dict for global step 2934: accuracy = 0.9896875, global_step = 2934, loss = 0.14604321
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2934: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-2934
# INFO:tensorflow:global_step/sec: 5.17035
# INFO:tensorflow:loss = 0.12447865, step = 2940 (3.868 sec)
# INFO:tensorflow:global_step/sec: 81.1764
# INFO:tensorflow:loss = 0.12690929, step = 2960 (0.247 sec)
# INFO:tensorflow:global_step/sec: 94.3112
# INFO:tensorflow:loss = 0.1447376, step = 2980 (0.211 sec)
# INFO:tensorflow:global_step/sec: 87.8274
# INFO:tensorflow:loss = 0.20281786, step = 3000 (0.229 sec)
# INFO:tensorflow:global_step/sec: 87.0619
# INFO:tensorflow:loss = 0.14799744, step = 3020 (0.228 sec)
# INFO:tensorflow:global_step/sec: 90.6057
# INFO:tensorflow:loss = 0.14694834, step = 3040 (0.221 sec)
# INFO:tensorflow:Saving checkpoints for 3056 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (5 secs).
# INFO:tensorflow:global_step/sec: 46.7788
# INFO:tensorflow:loss = 0.15596946, step = 3060 (0.428 sec)
# INFO:tensorflow:global_step/sec: 90.6785
# INFO:tensorflow:loss = 0.11987162, step = 3080 (0.220 sec)
# INFO:tensorflow:global_step/sec: 87.7192
# INFO:tensorflow:loss = 0.12451046, step = 3100 (0.229 sec)
# INFO:tensorflow:global_step/sec: 90.7587
# INFO:tensorflow:loss = 0.13850632, step = 3120 (0.219 sec)
# INFO:tensorflow:global_step/sec: 92.0436
# INFO:tensorflow:loss = 0.16186965, step = 3140 (0.217 sec)
# INFO:tensorflow:global_step/sec: 85.1102
# INFO:tensorflow:loss = 0.16772223, step = 3160 (0.235 sec)
# INFO:tensorflow:global_step/sec: 88.1114
# INFO:tensorflow:loss = 0.1578994, step = 3180 (0.227 sec)
# INFO:tensorflow:global_step/sec: 91.0911
# INFO:tensorflow:loss = 0.15652095, step = 3200 (0.220 sec)
# INFO:tensorflow:global_step/sec: 83.268
# INFO:tensorflow:loss = 0.15500045, step = 3220 (0.240 sec)
# INFO:tensorflow:global_step/sec: 90.5252
# INFO:tensorflow:loss = 0.12324783, step = 3240 (0.221 sec)
# INFO:tensorflow:global_step/sec: 86.5634
# INFO:tensorflow:loss = 0.12058544, step = 3260 (0.231 sec)
# INFO:tensorflow:global_step/sec: 88.2626
# INFO:tensorflow:loss = 0.14210407, step = 3280 (0.227 sec)
# INFO:tensorflow:global_step/sec: 82.687
# INFO:tensorflow:loss = 0.14237304, step = 3300 (0.243 sec)
# INFO:tensorflow:global_step/sec: 86.2768
# INFO:tensorflow:loss = 0.121409334, step = 3320 (0.231 sec)
# INFO:tensorflow:global_step/sec: 94.8486
# INFO:tensorflow:loss = 0.15660451, step = 3340 (0.211 sec)
# INFO:tensorflow:global_step/sec: 85.5304
# INFO:tensorflow:loss = 0.12021802, step = 3360 (0.234 sec)
# INFO:tensorflow:global_step/sec: 87.7415
# INFO:tensorflow:loss = 0.123819344, step = 3380 (0.228 sec)
# INFO:tensorflow:global_step/sec: 90.8226
# INFO:tensorflow:loss = 0.15083933, step = 3400 (0.221 sec)
# INFO:tensorflow:global_step/sec: 87.5318
# INFO:tensorflow:loss = 0.1520548, step = 3420 (0.227 sec)
# INFO:tensorflow:global_step/sec: 90.0987
# INFO:tensorflow:loss = 0.17854598, step = 3440 (0.222 sec)
# INFO:tensorflow:global_step/sec: 87.8073
# INFO:tensorflow:loss = 0.19239204, step = 3460 (0.228 sec)
# INFO:tensorflow:Saving checkpoints for 3480 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:35:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-3480
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:35:17
# INFO:tensorflow:Saving dict for global step 3480: accuracy = 0.9884375, global_step = 3480, loss = 0.15487622
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3480: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-3480
# INFO:tensorflow:global_step/sec: 4.69746
# INFO:tensorflow:loss = 0.1378098, step = 3480 (4.258 sec)
# INFO:tensorflow:global_step/sec: 78.2446
# INFO:tensorflow:loss = 0.13971762, step = 3500 (0.256 sec)
# INFO:tensorflow:global_step/sec: 89.5809
# INFO:tensorflow:loss = 0.12493763, step = 3520 (0.223 sec)
# INFO:tensorflow:global_step/sec: 84.4446
# INFO:tensorflow:loss = 0.12861136, step = 3540 (0.236 sec)
# INFO:tensorflow:global_step/sec: 85.2662
# INFO:tensorflow:loss = 0.12611765, step = 3560 (0.235 sec)
# INFO:tensorflow:Saving checkpoints for 3562 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (5 secs).
# INFO:tensorflow:global_step/sec: 48.7198
# INFO:tensorflow:loss = 0.12526965, step = 3580 (0.411 sec)
# INFO:tensorflow:global_step/sec: 98.4402
# INFO:tensorflow:loss = 0.13862783, step = 3600 (0.204 sec)
# INFO:tensorflow:global_step/sec: 86.9411
# INFO:tensorflow:loss = 0.14638199, step = 3620 (0.229 sec)
# INFO:tensorflow:global_step/sec: 87.218
# INFO:tensorflow:loss = 0.11959059, step = 3640 (0.229 sec)
# INFO:tensorflow:global_step/sec: 90.9695
# INFO:tensorflow:loss = 0.11621204, step = 3660 (0.219 sec)
# INFO:tensorflow:global_step/sec: 89.0661
# INFO:tensorflow:loss = 0.12149239, step = 3680 (0.225 sec)
# INFO:tensorflow:global_step/sec: 83.5841
# INFO:tensorflow:loss = 0.11899513, step = 3700 (0.240 sec)
# INFO:tensorflow:global_step/sec: 81.9209
# INFO:tensorflow:loss = 0.1375334, step = 3720 (0.243 sec)
# INFO:tensorflow:global_step/sec: 82.3452
# INFO:tensorflow:loss = 0.12817849, step = 3740 (0.243 sec)
# INFO:tensorflow:global_step/sec: 85.8594
# INFO:tensorflow:loss = 0.12203427, step = 3760 (0.233 sec)
# INFO:tensorflow:global_step/sec: 94.537
# INFO:tensorflow:loss = 0.11666903, step = 3780 (0.211 sec)
# INFO:tensorflow:global_step/sec: 87.6039
# INFO:tensorflow:loss = 0.12052907, step = 3800 (0.230 sec)
# INFO:tensorflow:global_step/sec: 88.4979
# INFO:tensorflow:loss = 0.11666692, step = 3820 (0.225 sec)
# INFO:tensorflow:global_step/sec: 86.8183
# INFO:tensorflow:loss = 0.17676294, step = 3840 (0.230 sec)
# INFO:tensorflow:global_step/sec: 85.0691
# INFO:tensorflow:loss = 0.116793245, step = 3860 (0.237 sec)
# INFO:tensorflow:global_step/sec: 94.7979
# INFO:tensorflow:loss = 0.11676109, step = 3880 (0.209 sec)
# INFO:tensorflow:global_step/sec: 92.4808
# INFO:tensorflow:loss = 0.1286106, step = 3900 (0.217 sec)
# INFO:tensorflow:global_step/sec: 100.733
# INFO:tensorflow:loss = 0.13468222, step = 3920 (0.198 sec)
# INFO:tensorflow:global_step/sec: 97.8254
# INFO:tensorflow:loss = 0.12881821, step = 3940 (0.205 sec)
# INFO:tensorflow:global_step/sec: 94.4882
# INFO:tensorflow:loss = 0.14381962, step = 3960 (0.212 sec)
# INFO:tensorflow:global_step/sec: 97.9194
# INFO:tensorflow:loss = 0.12938346, step = 3980 (0.204 sec)
# INFO:tensorflow:Saving checkpoints for 3997 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:35:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-3997
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:35:26
# INFO:tensorflow:Saving dict for global step 3997: accuracy = 0.988125, global_step = 3997, loss = 0.15315452
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3997: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-3997
# INFO:tensorflow:Saving checkpoints for 4000 into /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (5 secs).
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-08-23:35:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-08-08-23:35:30
# INFO:tensorflow:Saving dict for global step 4000: accuracy = 0.9875, global_step = 4000, loss = 0.15892813
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: /tmp/resnet_mnist_snnl/with_snnl_loss/model.ckpt-4000
# INFO:tensorflow:Loss for final step: 0.12583056.
# ({'accuracy': 0.9875, 'global_step': 4000, 'loss': 0.15892813}, [])

# %% [markdown]
# ## Evaluation

# %%
tf.logging.set_verbosity(tf.logging.INFO)

b_size = 64

learning_rate = 0.001

random_seed = 777

num_steps = 4000

tf.summary.FileWriterCache.clear()

model_path = "/tmp/resnet_mnist_snnl/with_snnl_loss/"
        
model_fn = lambda features, labels, mode: resnet10_model_fn(features, labels, mode, conv_kernel=7, num_channels=8, log=True)

mnist = input_data.read_data_sets("/tmp/data/", one_hot=False)

# Define the input function for training
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x=mnist.train.images, y=mnist.train.labels, batch_size=b_size, num_epochs=None, shuffle=True)

eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x=mnist.test.images, y=mnist.test.labels, batch_size=b_size, num_epochs=None, shuffle=True)



model = tf.estimator.Estimator(model_fn=model_fn, model_dir=model_path)

model.evaluate(eval_input_fn)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/resnet_mnist_snnl/with_snnl_loss/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3eb42decc0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# in gpu part
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-58a574e715df> in <module>()
#      29 model = tf.estimator.Estimator(model_fn=model_fn, model_dir=model_path)
#      30
# ---> 31 model.evaluate(eval_input_fn)
#      32
#      33
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py in evaluate(self, input_fn, steps, hooks, checkpoint_path, name)
#     474             return _evaluate()
#     475         else:
# --> 476           return _evaluate()
#     477
#     478   def _convert_eval_steps_to_hooks(self, steps):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py in _evaluate()
#     460       def _evaluate():
#     461         (scaffold, update_op, eval_dict, all_hooks) = (
# --> 462             self._evaluate_build_graph(input_fn, hooks, checkpoint_path))
#     463         return self._evaluate_run(
#     464             checkpoint_path=checkpoint_path,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py in _evaluate_build_graph(self, input_fn, hooks, checkpoint_path)
#    1420     else:
#    1421       (scaffold, evaluation_hooks, input_hooks, update_op, eval_dict) = (
# -> 1422           self._call_model_fn_eval(input_fn, self.config))
#    1423
#    1424     global_step_tensor = training_util.get_global_step(ops.get_default_graph())
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py in _call_model_fn_eval(self, input_fn, config)
#    1456
#    1457     estimator_spec = self._call_model_fn(
# -> 1458         features, labels, model_fn_lib.ModeKeys.EVAL, config)
#    1459     eval_metric_ops = _verify_and_create_loss_metric(
#    1460         estimator_spec.eval_metric_ops, estimator_spec.loss)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1167
#    1168     logging.info('Calling model_fn.')
# -> 1169     model_fn_results = self._model_fn(features=features, **kwargs)
#    1170     logging.info('Done calling model_fn.')
#    1171
#
# <ipython-input-12-58a574e715df> in <lambda>(features, labels, mode)
#      14 model_path = "/tmp/resnet_mnist_snnl/with_snnl_loss/"
#      15
# ---> 16 model_fn = lambda features, labels, mode: resnet10_model_fn(features, labels, mode, conv_kernel=7, num_channels=8, log=True)
#      17
#      18 mnist = input_data.read_data_sets("/tmp/data/", one_hot=False)
#
# <ipython-input-9-8bf32fbdb0e1> in resnet10_model_fn(features, labels, mode, conv_kernel, resblock_kernel, num_channels, snnl_weight, log)
#     117             conv0_weights = [v for v in tf.global_variables() if v.name == "Resnet-10/conv_0/conv2d/kernel:0"][0]
#     118
# --> 119             plot_op_expanded = tf.expand_dims(log_util.plot_conv_weights(conv0_weights), 0)
#     120             tf.summary.image("conv_0_weight_plots", plot_op_expanded)
#     121
#
# NameError: name 'log_util' is not defined
