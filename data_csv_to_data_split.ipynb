# %% [markdown]
# # Dependencies
#
# ```pip install shutil```
#
# ```pip install mritopng```

# %% [markdown]
# # Get Ratings from CSV

# %%
import csv

# returns a list of pairs of DICOM file names and their respective label
# returns 3 for any unlablled image
def get_ratings_list(log_path, name_index = 1, label_index=2):
    
    ratings_list = []
    
    with open(log_path) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')

        row_count = 0

        for row in csv_reader:

            # ignore column name row
            if (row_count != 0):
                
                if (int(row[label_index]) > 2):
                    ratings_list.append([row[name_index], 3])
                else:
                    
                    ratings_list.append([row[name_index], int(row[label_index])])

            row_count = row_count + 1
        
    return ratings_list

# %% [markdown]
# # Generate Folder Structure from CSV (3-class)

# %%
import shutil
import mritopng
import os

# generates a data folder where the subfolder are labels and the subfolder of those labels are converted PNG images

#####------ ADJUST SETTINGS BELOW ------#####

log_path = "./data/logs/"
data_pool_path = "./data/data_pool_dicom/"
output_dir = "./data/generated_sets/3class/"

rater_log_paths = ["ratings_ali.csv", 
                   "ratings_peter.csv", 
                   "ratings_ali.csv", 
                   "ratings_peter.csv"]

output_paths = ["ali_labels_original/", 
                "peter_labels_original/", 
                "ali_labels_undersampled/", 
                "peter_labels_undersampled/" ]

my_name_index = 1 # column index of the DICOM filename in the CSV log
my_label_index = 2 # column index of the label to choose (2 for rating 1, 3 for rating 2)

#####------ ADJUST SETTINGS ABOVE ------#####


for rater_log, output_path in zip(rater_log_paths, output_paths):
    
    print("using rater log: " + rater_log)
    print("outputting to: " + output_dir + output_path)
    
    # start with new folder
    if os.path.exists(output_dir + output_path):
        shutil.rmtree(output_dir + output_path)
    os.mkdir(output_dir + output_path)

    # create subfolders
    os.mkdir(output_dir + output_path + "0/")
    os.mkdir(output_dir + output_path + "1/")
    os.mkdir(output_dir + output_path + "2/")

    # get ratings list
    ratings = get_ratings_list(log_path + rater_log, name_index=my_name_index, label_index=my_label_index)
    
    # progress display
    total_len = len(ratings)
    count = 0
    
    for elem in ratings:

        if (count % 100 == 0):
            print("progress: " + str(count) + "/" + str(total_len))

        # ignore DICOMs with no label (labeled as 100+)
        if (elem[1] <= 2):
            
            # try to convert file
            try:
                mritopng.convert_file(data_pool_path + elem[0],  
                                      output_dir + output_path + str(elem[1]) + "/" + elem[0] + ".png")

            except Exception as err:
                
                print(err)
                print(data_pool_path + elem[0])
            
            
        count = count + 1

# above seems to take care of contrast as well
# Out:
# using rater log: ratings_ali.csv
# outputting to: ./data/generated_sets/3class/ali_labels_original/
# progress: 0/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/ali_labels_original/3/IM-0022-0025-0001.dcm.png'
# ./data/data_pool_dicom/IM-0022-0025-0001.dcm
# progress: 100/2111
# progress: 200/2111
# progress: 300/2111
# progress: 400/2111
# progress: 500/2111
# progress: 600/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/ali_labels_original/3/IM-0070-0005-0001.dcm.png'
# ./data/data_pool_dicom/IM-0070-0005-0001.dcm
# progress: 700/2111
# progress: 800/2111
# progress: 900/2111
# progress: 1000/2111
# progress: 1100/2111
# progress: 1200/2111
# progress: 1300/2111
# progress: 1400/2111
# progress: 1500/2111
# progress: 1600/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/ali_labels_original/3/IM-0038-0009-0001.dcm.png'
# ./data/data_pool_dicom/IM-0038-0009-0001.dcm
# progress: 1700/2111
# progress: 1800/2111
# progress: 1900/2111
# progress: 2000/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/ali_labels_original/3/IM-0035-0006-0001.dcm.png'
# ./data/data_pool_dicom/IM-0035-0006-0001.dcm
# progress: 2100/2111
# using rater log: ratings_peter.csv
# outputting to: ./data/generated_sets/3class/peter_labels_original/
# progress: 0/2111
# progress: 100/2111
# Removing existing output file ./data/generated_sets/3class/peter_labels_original/0/IM-0012-0004-0001.dcm.png
# Removing existing output file ./data/generated_sets/3class/peter_labels_original/0/IM-0012-0004-0001.dcm.png
# [Errno 2] No such file or directory: './data/generated_sets/3class/peter_labels_original/3/IM-0031-0009-0001.dcm.png'
# ./data/data_pool_dicom/IM-0031-0009-0001.dcm
# progress: 200/2111
# Removing existing output file ./data/generated_sets/3class/peter_labels_original/1/IM-0061-0007-0001.dcm.png
# Removing existing output file ./data/generated_sets/3class/peter_labels_original/1/IM-0061-0007-0001.dcm.png
# progress: 300/2111
# progress: 400/2111
# progress: 500/2111
# progress: 600/2111
# progress: 700/2111
# progress: 800/2111
# progress: 900/2111
# progress: 1000/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/peter_labels_original/3/IM-0003-0006-0001.dcm.png'
# ./data/data_pool_dicom/IM-0003-0006-0001.dcm
# progress: 1100/2111
# progress: 1200/2111
# Removing existing output file ./data/generated_sets/3class/peter_labels_original/0/IM-0030-0022-0001.dcm.png
# Removing existing output file ./data/generated_sets/3class/peter_labels_original/0/IM-0030-0022-0001.dcm.png
# Removing existing output file ./data/generated_sets/3class/peter_labels_original/0/IM-0030-0022-0001.dcm.png
# progress: 1300/2111
# Removing existing output file ./data/generated_sets/3class/peter_labels_original/1/IM-0030-0006-0001.dcm.png
# progress: 1400/2111
# progress: 1500/2111
# progress: 1600/2111
# progress: 1700/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/peter_labels_original/3/IM-0045-0020-0001.dcm.png'
# ./data/data_pool_dicom/IM-0045-0020-0001.dcm
# progress: 1800/2111
# progress: 1900/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/peter_labels_original/3/IM-0017-0019-0001.dcm.png'
# ./data/data_pool_dicom/IM-0017-0019-0001.dcm
# progress: 2000/2111
# progress: 2100/2111
# using rater log: ratings_ali.csv
# outputting to: ./data/generated_sets/3class/ali_labels_undersampled/
# progress: 0/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/ali_labels_undersampled/3/IM-0022-0025-0001.dcm.png'
# ./data/data_pool_dicom/IM-0022-0025-0001.dcm
# progress: 100/2111
# progress: 200/2111
# progress: 300/2111
# progress: 400/2111
# progress: 500/2111
# progress: 600/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/ali_labels_undersampled/3/IM-0070-0005-0001.dcm.png'
# ./data/data_pool_dicom/IM-0070-0005-0001.dcm
# progress: 700/2111
# progress: 800/2111
# progress: 900/2111
# progress: 1000/2111
# progress: 1100/2111
# progress: 1200/2111
# progress: 1300/2111
# progress: 1400/2111
# progress: 1500/2111
# progress: 1600/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/ali_labels_undersampled/3/IM-0038-0009-0001.dcm.png'
# ./data/data_pool_dicom/IM-0038-0009-0001.dcm
# progress: 1700/2111
# progress: 1800/2111
# progress: 1900/2111
# progress: 2000/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/ali_labels_undersampled/3/IM-0035-0006-0001.dcm.png'
# ./data/data_pool_dicom/IM-0035-0006-0001.dcm
# progress: 2100/2111
# using rater log: ratings_peter.csv
# outputting to: ./data/generated_sets/3class/peter_labels_undersampled/
# progress: 0/2111
# progress: 100/2111
# Removing existing output file ./data/generated_sets/3class/peter_labels_undersampled/0/IM-0012-0004-0001.dcm.png
# Removing existing output file ./data/generated_sets/3class/peter_labels_undersampled/0/IM-0012-0004-0001.dcm.png
# [Errno 2] No such file or directory: './data/generated_sets/3class/peter_labels_undersampled/3/IM-0031-0009-0001.dcm.png'
# ./data/data_pool_dicom/IM-0031-0009-0001.dcm
# progress: 200/2111
# Removing existing output file ./data/generated_sets/3class/peter_labels_undersampled/1/IM-0061-0007-0001.dcm.png
# Removing existing output file ./data/generated_sets/3class/peter_labels_undersampled/1/IM-0061-0007-0001.dcm.png
# progress: 300/2111
# progress: 400/2111
# progress: 500/2111
# progress: 600/2111
# progress: 700/2111
# progress: 800/2111
# progress: 900/2111
# progress: 1000/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/peter_labels_undersampled/3/IM-0003-0006-0001.dcm.png'
# ./data/data_pool_dicom/IM-0003-0006-0001.dcm
# progress: 1100/2111
# progress: 1200/2111
# Removing existing output file ./data/generated_sets/3class/peter_labels_undersampled/0/IM-0030-0022-0001.dcm.png
# Removing existing output file ./data/generated_sets/3class/peter_labels_undersampled/0/IM-0030-0022-0001.dcm.png
# Removing existing output file ./data/generated_sets/3class/peter_labels_undersampled/0/IM-0030-0022-0001.dcm.png
# progress: 1300/2111
# Removing existing output file ./data/generated_sets/3class/peter_labels_undersampled/1/IM-0030-0006-0001.dcm.png
# progress: 1400/2111
# progress: 1500/2111
# progress: 1600/2111
# progress: 1700/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/peter_labels_undersampled/3/IM-0045-0020-0001.dcm.png'
# ./data/data_pool_dicom/IM-0045-0020-0001.dcm
# progress: 1800/2111
# progress: 1900/2111
# [Errno 2] No such file or directory: './data/generated_sets/3class/peter_labels_undersampled/3/IM-0017-0019-0001.dcm.png'
# ./data/data_pool_dicom/IM-0017-0019-0001.dcm
# progress: 2000/2111
# progress: 2100/2111

# %% [markdown]
# # Generate Folder Structure from CSV (2-class)

# %%
import shutil
import mritopng
import os

# same idea as above block, just with only two classes

#####------ ADJUST SETTINGS BELOW ------#####

log_path = "./data/logs/"
data_pool_path = "./data/data_pool_dicom/"
output_dir = "./data/generated_sets/2class/"

rater_log_paths = ["ratings_ali.csv", "ratings_peter.csv"]
output_paths = ["ali_labels_undersampled/", "peter_labels_undersampled/"]

#####------ ADJUST SETTINGS ABOVE ------#####

for rater_log, output_path in zip(rater_log_paths, output_paths):
    
    print("using rater log: " + rater_log)
    print("outputting to: " + output_dir + output_path)
    
    if os.path.exists(output_dir + output_path):
        shutil.rmtree(output_dir + output_path)
        
    os.mkdir(output_dir + output_path)

    os.mkdir(output_dir + output_path + "0/")
    os.mkdir(output_dir + output_path + "1/")

    ratings = get_ratings_list(log_path + rater_log)
    
    total_len = len(ratings)
    count = 0
    
    for elem in ratings:

        
        if (count % 100 == 0):
            print("progress: " + str(count) + "/" + str(total_len))

        if (elem[1] <= 2):
            
            try:
                
                if elem[1] == 1 or elem[1] == 2:
                
                    mritopng.convert_file(data_pool_path + elem[0],  
                                          output_dir + output_path + str(1) + "/" + elem[0] + ".png")
                else:
                    
                    mritopng.convert_file(data_pool_path + elem[0],  
                                          output_dir + output_path + str(0) + "/" + elem[0] + ".png")

            except Exception as err:
                
                print(err)
                print(data_pool_path + elem[0])
            
            
        count = count + 1
# Out:
# using rater log: ratings_ali.csv
# outputting to: ./data/generated_sets/2class/ali_labels_undersampled/
# progress: 0/2111
# progress: 100/2111
# progress: 200/2111
# progress: 300/2111
# progress: 400/2111
# progress: 500/2111
# progress: 600/2111
# progress: 700/2111
# progress: 800/2111
# progress: 900/2111
# progress: 1000/2111
# progress: 1100/2111
# progress: 1200/2111
# progress: 1300/2111
# progress: 1400/2111
# progress: 1500/2111
# progress: 1600/2111
# progress: 1700/2111
# progress: 1800/2111
# progress: 1900/2111
# progress: 2000/2111
# progress: 2100/2111
# using rater log: ratings_peter.csv
# outputting to: ./data/generated_sets/2class/peter_labels_undersampled/
# progress: 0/2111
# progress: 100/2111
# Removing existing output file ./data/generated_sets/2class/peter_labels_undersampled/0/IM-0012-0004-0001.dcm.png
# Removing existing output file ./data/generated_sets/2class/peter_labels_undersampled/0/IM-0012-0004-0001.dcm.png
# progress: 200/2111
# Removing existing output file ./data/generated_sets/2class/peter_labels_undersampled/1/IM-0061-0007-0001.dcm.png
# Removing existing output file ./data/generated_sets/2class/peter_labels_undersampled/1/IM-0061-0007-0001.dcm.png
# progress: 300/2111
# progress: 400/2111
# progress: 500/2111
# progress: 600/2111
# progress: 700/2111
# progress: 800/2111
# progress: 900/2111
# progress: 1000/2111
# progress: 1100/2111
# progress: 1200/2111
# Removing existing output file ./data/generated_sets/2class/peter_labels_undersampled/0/IM-0030-0022-0001.dcm.png
# Removing existing output file ./data/generated_sets/2class/peter_labels_undersampled/0/IM-0030-0022-0001.dcm.png
# Removing existing output file ./data/generated_sets/2class/peter_labels_undersampled/0/IM-0030-0022-0001.dcm.png
# progress: 1300/2111
# Removing existing output file ./data/generated_sets/2class/peter_labels_undersampled/1/IM-0030-0006-0001.dcm.png
# progress: 1400/2111
# progress: 1500/2111
# progress: 1600/2111
# progress: 1700/2111
# progress: 1800/2111
# progress: 1900/2111
# progress: 2000/2111
# progress: 2100/2111

# %% [markdown]
# # Split into Train, Eval, Test

# %%
import util.load_data_utility as load_data_utility
import shutil
import os
import pathlib

#####------ ADJUST SETTINGS BELOW ------#####

# input data roots must be output directories from the folders above (must have the 0/, 1/, etc structure already)

data_roots = ["./data/generated_sets/3class_rating2/ali_labels/",
              "./data/generated_sets/3class_rating2/ali_labels_undersampled//",
              "./data/generated_sets/3class_rating2/peter_labels/",
              "./data/generated_sets/3class_rating2/peter_labels_undersampled//"]

output_folders = ["./data/generated_splits/3class_rating2/ali_relabeled_original/",
                  "./data/generated_splits/3class_rating2/ali_relabeled_undersampled/",
                  "./data/generated_splits/3class_rating2/peter_relabeled_original/",
                  "./data/generated_splits/3class_rating2/peter_relabeled_undersampled/"]

split_ratios = [0.7, 0.1, 0.2]

#####------ ADJUST SETTINGS ABOVE ------#####

for data_root, output_folder in zip(data_roots, output_folders):

    image_paths = load_data_utility.load_image_paths(data_root)

    print(image_paths[:5])

    train_paths, eval_paths, test_paths = load_data_utility.split(image_paths, split=split_ratios, seed=777)

    # get parent directory for label
    def get_label(path):

        path_location = pathlib.Path(path)

        str1 = str(path_location.parents[0])
        str2 = str(path_location.parents[1])

        retval = str1.replace(str2, '')
        retval = retval.replace("/", '')

        return retval


    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)

    os.mkdir(output_folder)
    os.mkdir(output_folder + "train/")
    os.mkdir(output_folder + "eval/")
    os.mkdir(output_folder + "test/")
    os.mkdir(output_folder + "train/0/")
    os.mkdir(output_folder + "train/1/")
    os.mkdir(output_folder + "train/2/")
    os.mkdir(output_folder + "eval/0/")
    os.mkdir(output_folder + "eval/1/")
    os.mkdir(output_folder + "eval/2/")
    os.mkdir(output_folder + "test/0/")
    os.mkdir(output_folder + "test/1/")
    os.mkdir(output_folder + "test/2/")


    for pngfile in train_paths:
        shutil.copy(pngfile, output_folder + "train/" + get_label(pngfile) + "/" )

    for pngfile in eval_paths:
        shutil.copy(pngfile, output_folder + "eval/" + get_label(pngfile) + "/" )

    for pngfile in test_paths:
        shutil.copy(pngfile, output_folder + "test/" + get_label(pngfile) + "/" )
# Out:
# ['data/generated_sets/3class_rating2/ali_labels/1/IM-0071-0019-0001.dcm.png', 'data/generated_sets/3class_rating2/ali_labels/1/IM-0017-0009-0001.dcm.png', 'data/generated_sets/3class_rating2/ali_labels/1/IM-0049-0016-0001.dcm.png', 'data/generated_sets/3class_rating2/ali_labels/1/IM-0030-0010-0001.dcm.png', 'data/generated_sets/3class_rating2/ali_labels/1/IM-0005-0019-0001.dcm.png']
# data/generated_sets/3class_rating2/ali_labels/2/IM-0016-0020-0001.dcm.png
# 2
# ['data/generated_sets/3class_rating2/ali_labels_undersampled/1/IM-0071-0019-0001.dcm.png', 'data/generated_sets/3class_rating2/ali_labels_undersampled/1/IM-0017-0009-0001.dcm.png', 'data/generated_sets/3class_rating2/ali_labels_undersampled/1/IM-0049-0016-0001.dcm.png', 'data/generated_sets/3class_rating2/ali_labels_undersampled/1/IM-0030-0010-0001.dcm.png', 'data/generated_sets/3class_rating2/ali_labels_undersampled/1/IM-0005-0019-0001.dcm.png']
# data/generated_sets/3class_rating2/ali_labels_undersampled/1/IM-0035-0011-0001.dcm.png
# 1
# ['data/generated_sets/3class_rating2/peter_labels/1/IM-0071-0019-0001.dcm.png', 'data/generated_sets/3class_rating2/peter_labels/1/IM-0017-0009-0001.dcm.png', 'data/generated_sets/3class_rating2/peter_labels/1/IM-0018-0018-0001.dcm.png', 'data/generated_sets/3class_rating2/peter_labels/1/IM-0007-0033-0001.dcm.png', 'data/generated_sets/3class_rating2/peter_labels/1/IM-0049-0016-0001.dcm.png']
# data/generated_sets/3class_rating2/peter_labels/1/IM-0054-0029-0001.dcm.png
# 1
# ['data/generated_sets/3class_rating2/peter_labels_undersampled/1/IM-0007-0033-0001.dcm.png', 'data/generated_sets/3class_rating2/peter_labels_undersampled/1/IM-0049-0016-0001.dcm.png', 'data/generated_sets/3class_rating2/peter_labels_undersampled/1/IM-0062-0018-0001.dcm.png', 'data/generated_sets/3class_rating2/peter_labels_undersampled/1/IM-0010-0002-0001.dcm.png', 'data/generated_sets/3class_rating2/peter_labels_undersampled/1/IM-0040-0029-0001.dcm.png']
# data/generated_sets/3class_rating2/peter_labels_undersampled/1/IM-0005-0009-0001.dcm.png
# 1

# %% [markdown]
# # Dataset Balancing

# %% [markdown]
# ## Balancing Utility Functions

# %%
import pathlib
import random

# load an array of image paths, indexed by their label
def load_sorted_paths(path):
    
    data_root = pathlib.Path(path)
    
    paths = []
    
    for child in sorted(data_root.iterdir(), key=(lambda x: x.name):
        if (child.is_dir() and child.name != ".DS_Store"):
            print(child)
            
            subdir_paths = list(child.glob('**/*'))
            subdir_paths = [str(path) for path in subdir_paths if path.name != ".DS_Store"]
        
            paths.append(subdir_paths)
            
    return paths

# load just an array of image paths
def load_dir_paths(path):
    
    data_root = pathlib.Path(path)
    
    paths = []
    
    for child in data_root.iterdir():
        if (child.name != ".DS_Store"):
         
            paths.append(str(child))
    
    return paths

# %% [markdown]
# ## Inserting Noisy Images

# %%
import synthetic_motion_utility as synth
import imageio

input_data_dir = "./data/generated_splits/train_set_balanced/train/1/"
output_data_dir = "./data/generated_splits/train_set_balanced/train/0/"

all_image_paths = load_dir_paths(input_data_dir)

num_synthetic = 400
counter = 0

random.seed(a=777)
random.shuffle(all_image_paths)

while counter < num_synthetic:
    
    im = imageio.imread(all_image_paths[counter])
    
    im = synth.add_motion_artifact(im, seed=counter)
    
    imageio.imwrite(output_data_dir + "synthetic_" + str(counter) + ".png", im)
    
    counter = counter + 1

# %% [markdown]
# ## Oversampling 2-Label Images

# %%
import os, glob, shutil

# directory of 2 label images to be oversampled
data_root_2 = "./data/generated_splits/train_set_balanced/train/2/"

# load image paths in in this directory
image_paths_2 = load_dir_paths(data_root_2)


# remove any pervious duplicates
for filename in glob.glob(data_root_2 + "duplicate*"):
    os.remove(filename) 

# oversample    
counter = 0
for pngfile in image_paths_2:
    shutil.copy(pngfile, data_root_2 + "duplicate_" +  str(counter) + ".png" )
    counter = counter + 1

# %% [markdown]
# ## Undersampling Images

# %%
import os
import random

random.seed(a=777)

# directory of set to be undersampled
data_root = "./data/generated_sets/3class/ali_labels_undersampled/"
data_root = data_root + "1/"

# get paths in directory
paths_in_dir = load_dir_paths(data_root)

#shuffle randomly
random.shuffle(paths_in_dir)

print(paths_in_dir[:10])

random.seed(a=777)

# randmoly remove half using random.choice
for path in paths_in_dir:
    
    if (random.choice([True, False])):
        print("removing: " + path)
        os.remove(path)
# Out:
# ['data/generated_sets/3class/ali_labels_undersampled/1/IM-0049-0004-0001.dcm.png', 'data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0030-0001.dcm.png', 'data/generated_sets/3class/ali_labels_undersampled/1/IM-0064-0016-0001.dcm.png', 'data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0019-0001.dcm.png', 'data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0024-0001.dcm.png', 'data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0027-0001.dcm.png', 'data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0008-0001.dcm.png', 'data/generated_sets/3class/ali_labels_undersampled/1/IM-0045-0003-0001.dcm.png', 'data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0022-0001.dcm.png', 'data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0005-0001.dcm.png']
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0049-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0032-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0048-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0005-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0023-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0005-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0050-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0029-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0016-0034-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0037-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0001-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0069-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0004-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0023-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0034-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0029-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0001-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0001-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0064-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0034-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0005-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0030-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0054-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0064-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0022-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0068-0034-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0045-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0046-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0034-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0026-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0026-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0008-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0032-0030-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0035-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0068-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0009-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0048-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0021-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0049-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0029-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0063-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0068-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0005-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0049-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0004-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0050-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0030-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0005-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0005-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0068-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0034-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0032-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0061-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0030-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0030-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0069-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0023-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0001-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0069-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0043-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0046-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0032-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0043-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0061-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0062-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0009-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0023-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0050-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0034-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0056-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0068-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0071-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0071-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0069-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0063-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0043-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0045-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0069-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0050-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0026-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0048-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0064-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0030-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0004-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0030-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0035-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0045-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0063-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0046-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0043-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0045-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0001-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0043-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0042-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0047-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0030-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0037-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0045-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0046-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0071-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0009-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0021-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0042-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0026-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0004-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0062-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0054-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0033-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0005-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0001-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0004-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0047-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0048-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0046-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0054-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0045-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0068-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0071-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0042-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0050-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0047-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0030-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0029-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0033-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0032-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0001-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0047-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0035-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0042-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0069-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0048-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0005-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0021-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0046-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0033-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0055-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0063-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0047-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0011-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0016-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0063-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0009-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0037-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0009-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0057-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0042-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0011-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0029-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0064-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0037-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0061-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0071-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0042-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0047-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0011-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0034-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0031-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0026-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0022-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0026-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0049-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0022-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0004-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0068-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0059-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0043-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0029-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0050-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0046-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0020-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0050-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0062-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0033-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0044-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0069-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0031-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0054-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0071-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0050-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0071-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0008-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0037-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0047-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0043-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0044-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0059-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0059-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0062-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0032-0031-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0064-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0071-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0061-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0061-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0050-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0009-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0049-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0040-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0001-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0009-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0022-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0026-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0045-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0047-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0004-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0031-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0030-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0030-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0037-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0030-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0056-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0064-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0069-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0064-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0054-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0059-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0008-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0031-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0037-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0034-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0032-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0045-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0033-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0063-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0023-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0007-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0026-0005-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0036-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0063-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0060-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0054-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0066-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0038-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0014-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0041-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0040-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0024-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0063-0015-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0029-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0061-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0061-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0049-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0046-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0042-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0017-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0053-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0052-0034-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0009-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0011-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0023-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0062-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0034-0028-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0058-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0023-0020-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0031-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0004-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0043-0022-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0019-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0054-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0032-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0014-0024-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0059-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0025-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0013-0019-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0032-0029-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0023-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0068-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0062-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0008-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0022-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0028-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0069-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0003-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0016-0026-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0029-0004-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0017-0010-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0065-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0001-0006-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0032-0023-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0056-0025-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0006-0027-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0011-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0018-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0046-0002-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0054-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0010-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0002-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0009-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0015-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0007-0021-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0067-0012-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0027-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0070-0011-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0012-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0051-0001-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0018-0013-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0042-0016-0001.dcm.png
# removing: data/generated_sets/3class/ali_labels_undersampled/1/IM-0003-0007-0001.dcm.png
