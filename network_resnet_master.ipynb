# %% [markdown]
# # Imports and General Settings

# %%
import tensorflow as tf
import tensorflow.contrib as tf_contrib

import os
import pathlib

import numpy as np

import io

import random

import pylab
import tfplot

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import tfx
import tensorflow_transform as tft

from cleverhans.loss import SNNLCrossEntropy

# import self utility functions
import util.model_arch_utility as model_arch
import util.log_utility as log_util
import util.data_augmentation_utility as da_util
import util.load_data_utility as load_data_util

# tensorflow specific settings
tf.enable_eager_execution()
tf.logging.set_verbosity(tf.logging.DEBUG)

# which GPU to be used (0 is RTX, 1 or 2 are either of the Titan Xps)
gpu = "/GPU:0"

AUTOTUNE = tf.contrib.data.AUTOTUNE

session_config = tf.ConfigProto()
session_config.gpu_options.allow_growth = True
session_config.allow_soft_placement = True

# session_config.log_device_placement = True
tf.keras.backend.set_session(tf.Session(config=session_config))

# make sure tensorflow-gpu is being used
print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %% [markdown]
# # Data Augmentation

# %%
def augment_image(image):
                       
    image = da_util.rotate(image)
    image = da_util.flip(image)
    
    image = da_util.translate(image)
    image = da_util.crop(image)

    return image

# %% [markdown]
# # ResNet

# %% [markdown]
# ## ResNet-10 Architecture

# %%
num_classes = 3

# ResNet-10 architecture
def resnet10_network(x, conv_kernel=7, resblock_kernel=3, num_channels=4, n_classes=num_classes, reuse = False, is_training = True):
    with tf.variable_scope('Resnet-10', reuse = reuse), tf.device(gpu):
        
#         x = tf.reshape(x, shape=[-1, 512, 512, 1])
        # channels
        
        filtered_images = []
        
        filtered_images.append(tf.identity(x))
        
        x = model_arch.conv(x, num_channels, kernel=conv_kernel, stride=1, padding='SAME')
        
        filtered_images.append(tf.identity(x))
        
        x = model_arch.resblock(x, channels=num_channels, kernel=resblock_kernel, is_training=is_training, 
                      downsample=False, scope='resblock1_id1')      
   
        filtered_images.append(tf.identity(x))

        x = model_arch.resblock(x, channels=num_channels * 2, kernel=resblock_kernel, is_training=is_training, 
                     downsample=True, scope='resblock2_conv1')
        
        filtered_images.append(tf.identity(x))

        x = model_arch.resblock(x, channels=num_channels * 2, kernel=resblock_kernel, is_training=is_training, 
                      downsample=False, scope='resblock3_id2')
        
        filtered_images.append(tf.identity(x))
        
        x = model_arch.resblock(x, channels=num_channels * 4, kernel=resblock_kernel, is_training=is_training, 
                     downsample=True, scope='resblock4_conv2')

        filtered_images.append(tf.identity(x))
        
        x = model_arch.resblock(x, channels=num_channels * 4, kernel=resblock_kernel, is_training=is_training, 
                      downsample=False, scope='resblock5_id3')
        
        filtered_images.append(tf.identity(x))
        
        
        x = model_arch.batch_norm(x, is_training, scope='batch_norm')
        
        x = model_arch.relu(x)
        
        x_pre_flatten = tf.identity(x)
        
        x = model_arch.fully_connected(x, num_classes)
        
        return x, x_pre_flatten, filtered_images

    
def resnet10_model_fn(features, labels, mode, conv_kernel=7, resblock_kernel=3, num_channels=4, snnl_weight=0.05,
                      log=True):
    with tf.device(gpu):

        print("in gpu part")
        logits_train, activ_maps_train, filtered_images = resnet10_network(features,
                                                          conv_kernel=conv_kernel,
                                                          resblock_kernel=resblock_kernel,
                                                          num_channels=num_channels,
                                                          n_classes=num_classes,
                                                          reuse=False,
                                                          is_training=True)

        logits_test, activ_maps_test, _ = resnet10_network(features,
                                                        conv_kernel=conv_kernel,
                                                        resblock_kernel=resblock_kernel,
                                                        num_channels=num_channels,
                                                        n_classes=num_classes,
                                                        reuse=True,
                                                        is_training=False)

        pred_classes = tf.arg_max(logits_test, dimension=1)

        # PREDICT MODE
        if mode == tf.estimator.ModeKeys.PREDICT:

            return tf.estimator.EstimatorSpec(mode=mode, predictions=pred_classes)


        loss_op = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits_train, labels=tf.cast(labels, dtype=tf.int32)))

        loss_op = (1.0 - snnl_weight) * loss_op + snnl_weight * SNNLCrossEntropy.optimized_temp_SNNL(
            model_arch.flatten(activ_maps_train), labels, 20.0, True)
        
        acc_op = tf.metrics.accuracy(labels=labels, predictions=pred_classes)

        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss_op, global_step=tf.train.get_global_step())
        
        tf.summary.scalar("loss", loss_op)
        tf.summary.scalar("accuracy", acc_op[1])
        
        if mode == tf.estimator.ModeKeys.TRAIN:
                

            # the different ops for training, evaluating, ...
            estim_specs = tf.estimator.EstimatorSpec(
                mode=mode,
                predictions=pred_classes,
                loss=loss_op,
                train_op=train_op,
                eval_metric_ops={'accuracy': acc_op}
            )

            return estim_specs
    
#     for var in tf.trainable_variables():
#         print(var.name)

        if (log):

            conv0_weights = [v for v in tf.global_variables() if v.name == "Resnet-10/conv_0/conv2d/kernel:0"][0]

            plot_op_expanded = tf.expand_dims(log_util.plot_conv_weights(conv0_weights), 0)
            tf.summary.image("conv_0_weight_plots", plot_op_expanded)


            with tf.name_scope("activation_maps"):

                level_dict = {0 : "0_original_image",         
                              1 : "1_after_initial_conv",
                              2 : "2_after_resblock1_id1",
                              3 : "3_after_resblock2_conv1",
                              4 : "4_after_resblock3_id2",
                              5 : "5_after_resblock4_conv2",
                              6 : "6_after_resblock5_id3"}

                counter = 0

                plot_ops = []

                for filtered_im in filtered_images:

                    activation_map = tf.slice(filtered_im,[0, 0, 0, 0],[1, -1, -1, -1])
                    activation_op = tf.expand_dims(log_util.plot_conv_output(activation_map, level_dict[counter]), 0)

                    plot_ops.append(activation_op)

                    counter = counter + 1

                final_log_op = tf.concat(plot_ops, 1)

                tf.summary.image("image_display", final_log_op)
        
        eval_summary_hook = tf.train.SummarySaverHook(
            save_steps=1,
            output_dir=model_path + "/eval_images",
            summary_op=tf.summary.merge_all())
        # Add it to the evaluation_hook list
        evaluation_hooks = []
        evaluation_hooks.append(eval_summary_hook)

        # the different ops for training, evaluating, ...
        estim_specs = tf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss_op,
            train_op=train_op,
            eval_metric_ops={'accuracy': acc_op},
            evaluation_hooks=evaluation_hooks
        )

        return estim_specs

# %% [markdown]
# ## ResNet-4 Architecture

# %%
num_classes = 2

# ResNet-10 architecture
def resnet4_network(x, conv_kernel=7, resblock_kernel=3, num_channels=4, n_classes=num_classes, reuse = False, is_training = True):
    with tf.variable_scope('Resnet-4', reuse = reuse), tf.device(gpu):
        
        x = tf.reshape(x, shape=[-1, 512, 512, 1])
        # channels
        
        filtered_images = []
        
        filtered_images.append(tf.identity(x)) # initial image
        
        x = model_arch.conv(x, num_channels, kernel=conv_kernel, stride=1, padding='SAME')
        
        filtered_images.append(tf.identity(x)) # post conv
        
        x = model_arch.resblock(x, channels=num_channels, kernel=resblock_kernel, is_training=is_training, 
                      downsample=False, scope='resblock1_id1')      
   
        filtered_images.append(tf.identity(x)) # post resblock

        x = model_arch.resblock(x, channels=num_channels * 2, kernel=resblock_kernel, is_training=is_training, 
                     downsample=True, scope='resblock2_conv1')
        
        filtered_images.append(tf.identity(x))
        
        x = model_arch.batch_norm(x, is_training, scope='batch_norm')
        
        x = model_arch.relu(x)
        
#         x = model_arch.max_pooling(x)
        
        x_pre_flatten = tf.identity(x)
        
        x = model_arch.fully_connected(x, num_classes)
        
        return x, x_pre_flatten, filtered_images

    
def resnet4_model_fn(features, labels, mode, conv_kernel=7, resblock_kernel=3, num_channels=4, snnl_weight=0.05,
                      log=True):
    with tf.device(gpu):

        print("in gpu part")
        logits_train, activ_maps_train, filtered_images = resnet4_network(features,
                                                          conv_kernel=conv_kernel,
                                                          resblock_kernel=resblock_kernel,
                                                          num_channels=num_channels,
                                                          n_classes=num_classes,
                                                          reuse=False,
                                                          is_training=True)

        logits_test, activ_maps_test, _ = resnet4_network(features,
                                                        conv_kernel=conv_kernel,
                                                        resblock_kernel=resblock_kernel,
                                                        num_channels=num_channels,
                                                        n_classes=num_classes,
                                                        reuse=True,
                                                        is_training=False)

        pred_classes = tf.arg_max(logits_test, dimension=1)

        # PREDICT MODE
        if mode == tf.estimator.ModeKeys.PREDICT:

            return tf.estimator.EstimatorSpec(mode=mode, predictions=pred_classes)


        loss_op = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits_train, labels=tf.cast(labels, dtype=tf.int32)))

        loss_op = (1.0 - snnl_weight) * loss_op + snnl_weight * SNNLCrossEntropy.optimized_temp_SNNL(
            model_arch.flatten(activ_maps_train), labels, 20.0, True)
        
        acc_op = tf.metrics.accuracy(labels=labels, predictions=pred_classes)

        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss_op, global_step=tf.train.get_global_step())
        
        tf.summary.scalar("loss", loss_op)
        tf.summary.scalar("accuracy", acc_op[1])
        
        if mode == tf.estimator.ModeKeys.TRAIN:
                

            # the different ops for training, evaluating, ...
            estim_specs = tf.estimator.EstimatorSpec(
                mode=mode,
                predictions=pred_classes,
                loss=loss_op,
                train_op=train_op,
                eval_metric_ops={'accuracy': acc_op}
            )

            return estim_specs
    
#     for var in tf.trainable_variables():
#         print(var.name)

        if (log):

            conv0_weights = [v for v in tf.global_variables() if v.name == "Resnet-4/conv_0/conv2d/kernel:0"][0]

            plot_op_expanded = tf.expand_dims(log_util.plot_conv_weights(conv0_weights), 0)
            tf.summary.image("conv_0_weight_plots", plot_op_expanded)

            with tf.name_scope("activation_maps"):

                level_dict = {0 : "0_original_image",         
                              1 : "1_after_initial_conv",
                              2 : "2_after_resblock1_id1",
                              3 : "3_after_resblock2_conv1"}

                counter = 0

                plot_ops = []

                for filtered_im in filtered_images:

                    activation_map = tf.slice(filtered_im,[0, 0, 0, 0],[1, -1, -1, -1])
                    activation_op = tf.expand_dims(log_util.plot_conv_output(activation_map, level_dict[counter]), 0)

                    plot_ops.append(activation_op)

                    counter = counter + 1

                final_log_op = tf.concat(plot_ops, 1)

                tf.summary.image("image_display", final_log_op)
        
        eval_summary_hook = tf.train.SummarySaverHook(
            save_steps=1,
            output_dir=model_path + "/eval_images",
            summary_op=tf.summary.merge_all())
        # Add it to the evaluation_hook list
        evaluation_hooks = []
        evaluation_hooks.append(eval_summary_hook)

        # the different ops for training, evaluating, ...
        estim_specs = tf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss_op,
            train_op=train_op,
            eval_metric_ops={'accuracy': acc_op},
            evaluation_hooks=evaluation_hooks
        )

        return estim_specs

# %% [markdown]
# ## ResNet-4 MaxPool Architecture

# %%
num_classes = 3

# ResNet-10 architecture
def resnet4_maxpool_network(x, conv_kernel=7, resblock_kernel=3, num_channels=4, n_classes=num_classes, reuse = False, is_training = True):
    with tf.variable_scope('Resnet-4-max-pool', reuse = reuse), tf.device(gpu):
        
        x = tf.reshape(x, shape=[-1, 512, 512, 1])
        # channels
        
        filtered_images = []
        
        filtered_images.append(tf.identity(x)) # initial image
        
        x = model_arch.conv(x, num_channels, kernel=conv_kernel, stride=1, padding='SAME')
        
        filtered_images.append(tf.identity(x)) # post conv
        
        x = model_arch.resblock(x, channels=num_channels, kernel=resblock_kernel, is_training=is_training, 
                      downsample=False, scope='resblock1_id1')      
   
        filtered_images.append(tf.identity(x)) # post resblock

        x = model_arch.resblock(x, channels=num_channels * 2, kernel=resblock_kernel, is_training=is_training, 
                     downsample=True, scope='resblock2_conv1')
        
        filtered_images.append(tf.identity(x))
        
        x = model_arch.batch_norm(x, is_training, scope='batch_norm')
        
        x = model_arch.relu(x)
        
        x = model_arch.max_pooling(x)
        
        x_pre_flatten = tf.identity(x)
        
        x = model_arch.fully_connected(x, num_classes)
        
        return x, x_pre_flatten, filtered_images

    
def resnet4_maxpool_model_fn(features, labels, mode, conv_kernel=7, resblock_kernel=3, num_channels=4, snnl_weight=0.05,
                      log=True):
    with tf.device(gpu):

        print("in gpu part")
        logits_train, activ_maps_train, filtered_images = resnet4_maxpool_network(features,
                                                          conv_kernel=conv_kernel,
                                                          resblock_kernel=resblock_kernel,
                                                          num_channels=num_channels,
                                                          n_classes=num_classes,
                                                          reuse=False,
                                                          is_training=True)

        logits_test, activ_maps_test, _ = resnet4_maxpool_network(features,
                                                        conv_kernel=conv_kernel,
                                                        resblock_kernel=resblock_kernel,
                                                        num_channels=num_channels,
                                                        n_classes=num_classes,
                                                        reuse=True,
                                                        is_training=False)

        pred_classes = tf.arg_max(logits_test, dimension=1)

        # PREDICT MODE
        if mode == tf.estimator.ModeKeys.PREDICT:

            return tf.estimator.EstimatorSpec(mode=mode, predictions=pred_classes)


        loss_op = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits_train, labels=tf.cast(labels, dtype=tf.int32)))

        loss_op = (1.0 - snnl_weight) * loss_op + snnl_weight * SNNLCrossEntropy.optimized_temp_SNNL(
            model_arch.flatten(activ_maps_train), labels, 20.0, True)
        
        acc_op = tf.metrics.accuracy(labels=labels, predictions=pred_classes)

        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss_op, global_step=tf.train.get_global_step())
        
        tf.summary.scalar("loss", loss_op)
        tf.summary.scalar("accuracy", acc_op[1])
        
        if mode == tf.estimator.ModeKeys.TRAIN:
                

            # the different ops for training, evaluating, ...
            estim_specs = tf.estimator.EstimatorSpec(
                mode=mode,
                predictions=pred_classes,
                loss=loss_op,
                train_op=train_op,
                eval_metric_ops={'accuracy': acc_op}
            )

            return estim_specs
    
#     for var in tf.trainable_variables():
#         print(var.name)

        if (log):

            conv0_weights = [v for v in tf.global_variables() if v.name == "Resnet-4-max-pool/conv_0/conv2d/kernel:0"][0]

            plot_op_expanded = tf.expand_dims(log_util.plot_conv_weights(conv0_weights), 0)
            tf.summary.image("conv_0_weight_plots", plot_op_expanded)


            with tf.name_scope("activation_maps"):

                level_dict = {0 : "0_original_image",         
                              1 : "1_after_initial_conv",
                              2 : "2_after_resblock1_id1",
                              3 : "3_after_resblock2_conv1"}

                counter = 0

                plot_ops = []

                for filtered_im in filtered_images:

                    activation_map = tf.slice(filtered_im,[0, 0, 0, 0],[1, -1, -1, -1])
                    
                    if (counter >= len(level_dict)):
                        name = ""
                    else:
                        name = level_dict[counter]
                    
                    
                    activation_op = tf.expand_dims(log_util.plot_conv_output(activation_map, name), 0)

                    plot_ops.append(activation_op)

                    counter = counter + 1

                final_log_op = tf.concat(plot_ops, 1)

                tf.summary.image("image_display", final_log_op)
        
        eval_summary_hook = tf.train.SummarySaverHook(
            save_steps=1,
            output_dir=model_path + "/eval_images",
            summary_op=tf.summary.merge_all())
        # Add it to the evaluation_hook list
        evaluation_hooks = []
        evaluation_hooks.append(eval_summary_hook)

        # the different ops for training, evaluating, ...
        estim_specs = tf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss_op,
            train_op=train_op,
            eval_metric_ops={'accuracy': acc_op},
            evaluation_hooks=evaluation_hooks
        )

        return estim_specs

# %% [markdown]
# ## ResNet-4 with Max Pooling

# %%
num_classes = 3

# ResNet-10 architecture
def resnet4_custom1_network(x, conv_kernel=7, num_channels=4, n_classes=num_classes, reuse = False, is_training = True):
    with tf.variable_scope('Resnet-4-10-3', reuse = reuse), tf.device(gpu):
        
        x = tf.reshape(x, shape=[-1, 512, 512, 1])
        # channels
        
        filtered_images = []
        
        filtered_images.append(tf.identity(x)) # initial image
        
        x = model_arch.conv(x, num_channels, kernel=conv_kernel, stride=1, padding='SAME')
        
        filtered_images.append(tf.identity(x)) # post conv
        
        x = model_arch.resblock(x, channels=num_channels, kernel=10, is_training=is_training, 
                      downsample=False, scope='resblock1_id1_kernel10')      
   
        filtered_images.append(tf.identity(x)) # post resblock

        x = model_arch.resblock(x, channels=num_channels * 2, kernel=3, is_training=is_training, 
                     downsample=True, scope='resblock2_conv1_kernel3')
        
        filtered_images.append(tf.identity(x))
        
        x = model_arch.batch_norm(x, is_training, scope='batch_norm')
        
        x = model_arch.relu(x)
        
        x_pre_flatten = tf.identity(x)
        
        x = model_arch.fully_connected(x, num_classes)
        
        return x, x_pre_flatten, filtered_images

    
def resnet4_custom1_model_fn(features, labels, mode, conv_kernel=7, num_channels=4, snnl_weight=0.05,
                      log=True):
    with tf.device(gpu):

        print("in gpu part")
        logits_train, activ_maps_train, filtered_images = resnet4_custom1_network(features,
                                                          conv_kernel=conv_kernel,
                                                          num_channels=num_channels,
                                                          n_classes=num_classes,
                                                          reuse=False,
                                                          is_training=True)

        logits_test, activ_maps_test, _ = resnet4_custom1_network(features,
                                                        conv_kernel=conv_kernel,
                                                        num_channels=num_channels,
                                                        n_classes=num_classes,
                                                        reuse=True,
                                                        is_training=False)

        pred_classes = tf.arg_max(logits_test, dimension=1)

        # PREDICT MODE
        if mode == tf.estimator.ModeKeys.PREDICT:

            return tf.estimator.EstimatorSpec(mode=mode, predictions=pred_classes)


        loss_op = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits_train, labels=tf.cast(labels, dtype=tf.int32)))

        loss_op = (1.0 - snnl_weight) * loss_op + snnl_weight * SNNLCrossEntropy.optimized_temp_SNNL(
            model_arch.flatten(activ_maps_train), labels, 20.0, True)
        
        acc_op = tf.metrics.accuracy(labels=labels, predictions=pred_classes)

        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss_op, global_step=tf.train.get_global_step())
        
        tf.summary.scalar("loss", loss_op)
        tf.summary.scalar("accuracy", acc_op[1])
        
        if mode == tf.estimator.ModeKeys.TRAIN:
                

            # the different ops for training, evaluating, ...
            estim_specs = tf.estimator.EstimatorSpec(
                mode=mode,
                predictions=pred_classes,
                loss=loss_op,
                train_op=train_op,
                eval_metric_ops={'accuracy': acc_op}
            )

            return estim_specs
    
#     for var in tf.trainable_variables():
#         print(var.name)

        if (log):

#             conv0_weights = [v for v in tf.global_variables() if v.name == "Resnet-4-max-pool/conv_0/conv2d/kernel:0"][0]

#             plot_op_expanded = tf.expand_dims(log_util.plot_conv_weights(conv0_weights), 0)
#             tf.summary.image("conv_0_weight_plots", plot_op_expanded)


            with tf.name_scope("activation_maps"):

                level_dict = {0 : "0_original_image",         
                              1 : "1_after_initial_conv",
                              2 : "2_after_resblock1_id1",
                              3 : "3_after_resblock2_conv1"}

                counter = 0

                plot_ops = []

                for filtered_im in filtered_images:

                    activation_map = tf.slice(filtered_im,[0, 0, 0, 0],[1, -1, -1, -1])
                    
                    if (counter >= len(level_dict)):
                        name = ""
                    else:
                        name = level_dict[counter]
                    
                    
                    activation_op = tf.expand_dims(log_util.plot_conv_output(activation_map, name), 0)

                    plot_ops.append(activation_op)

                    counter = counter + 1

                final_log_op = tf.concat(plot_ops, 1)

                tf.summary.image("image_display", final_log_op)
        
        eval_summary_hook = tf.train.SummarySaverHook(
            save_steps=1,
            output_dir=model_path + "/eval_images",
            summary_op=tf.summary.merge_all())
        # Add it to the evaluation_hook list
        evaluation_hooks = []
        evaluation_hooks.append(eval_summary_hook)

        # the different ops for training, evaluating, ...
        estim_specs = tf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss_op,
            train_op=train_op,
            eval_metric_ops={'accuracy': acc_op},
            evaluation_hooks=evaluation_hooks
        )

        return estim_specs

# %% [markdown]
# # Running Results

# %% [markdown]
# ## Experimentation

# %%
tf.logging.set_verbosity(tf.logging.INFO)

b_size = 32

learning_rate = 0.005

random_seed = 777

num_steps = 10000

# DOUBLE CHECK THIS
resnet4_checkpoint_path_base = "/data/jma/model/resnet4_experiment/"

# kernel_sizes = [7, 9, 10, 11, 13]
# filter_sizes = [10]
# snnl_weights = [0.0]

kernel_sizes = [5]
filter_sizes = [8]
snnl_weights = [0.00]

data_root = "./data/generated_sets/2class/ali_labels/"

image_paths = load_data_util.load_image_paths(data_root)
train_paths, eval_paths, test_paths = load_data_util.split(image_paths, seed=random_seed)

train_input_fn = lambda : load_data_util.load(data_root, train_paths, training=True, augment=False, batch_size=32, shuffle=False)
eval_input_fn = lambda : load_data_util.load(data_root, eval_paths, training=False, augment=False, batch_size=32, shuffle=False)
test_input_fn = lambda : load_data_util.load(data_root, test_paths, training=False, augment=False, shuffle=False)

for filter_size in filter_sizes:
    for kernel_size in kernel_sizes:
        
        for snnl_weight in snnl_weights:
            tf.summary.FileWriterCache.clear()
 
            model_path = resnet4_checkpoint_path_base + "kernel" + str(kernel_size) + "_filter" + str(filter_size) + "_snnl" + str(snnl_weight)+"/"
            print(model_path)

            config = tf.estimator.RunConfig(
                log_step_count_steps= 20,
                save_summary_steps= 30,
                save_checkpoints_secs= 120,
                model_dir=model_path,
                tf_random_seed=random_seed,
                session_config=session_config)

            # DOUBLE CHECK THIS
            model_fn = lambda features, labels, mode: resnet4_model_fn(features, labels, mode, 
                                                                        conv_kernel=kernel_size, 
                                                                        num_channels=filter_size,
                                                                        snnl_weight=snnl_weight,
                                                                        log=False)

            model = tf.estimator.Estimator(model_fn=model_fn, config=config)

            train_spec = tf.estimator.TrainSpec(input_fn=train_input_fn, max_steps=num_steps)
            eval_spec = tf.estimator.EvalSpec(input_fn=eval_input_fn, throttle_secs=120)

            tf.estimator.train_and_evaluate(model, train_spec, eval_spec)
# Out:
# /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/
# INFO:tensorflow:Using config: {'_model_dir': '/data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/', '_tf_random_seed': 777, '_save_summary_steps': 30, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 120, '_session_config': gpu_options {
#   allow_growth: true
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 20, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f446476dcc0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 120.
# pre-processing
# using norm
# shuffling and repeating b/c training flag set
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt.
# INFO:tensorflow:loss = 0.7524463, step = 0
# INFO:tensorflow:global_step/sec: 4.73175
# INFO:tensorflow:loss = 78.38075, step = 20 (4.230 sec)
# INFO:tensorflow:global_step/sec: 4.27493
# INFO:tensorflow:loss = 1.1879929, step = 40 (4.676 sec)
# INFO:tensorflow:global_step/sec: 5.36213
# INFO:tensorflow:loss = 30.16335, step = 60 (3.734 sec)
# INFO:tensorflow:global_step/sec: 5.58716
# INFO:tensorflow:loss = 0.24766749, step = 80 (3.576 sec)
# INFO:tensorflow:global_step/sec: 5.323
# INFO:tensorflow:loss = 3.7817845, step = 100 (3.759 sec)
# INFO:tensorflow:global_step/sec: 5.36649
# INFO:tensorflow:loss = 0.17367128, step = 120 (3.728 sec)
# INFO:tensorflow:global_step/sec: 5.49072
# INFO:tensorflow:loss = 1.3477964, step = 140 (3.639 sec)
# INFO:tensorflow:global_step/sec: 5.4037
# INFO:tensorflow:loss = 0.0, step = 160 (3.704 sec)
# INFO:tensorflow:global_step/sec: 5.29867
# INFO:tensorflow:loss = 1.4020112, step = 180 (3.775 sec)
# INFO:tensorflow:global_step/sec: 5.58787
# INFO:tensorflow:loss = 4.4729652, step = 200 (3.575 sec)
# INFO:tensorflow:global_step/sec: 5.26929
# INFO:tensorflow:loss = 0.0, step = 220 (3.797 sec)
# INFO:tensorflow:global_step/sec: 5.53082
# INFO:tensorflow:loss = 1.1140357e-05, step = 240 (3.616 sec)
# INFO:tensorflow:global_step/sec: 5.27809
# INFO:tensorflow:loss = 0.18966225, step = 260 (3.791 sec)
# INFO:tensorflow:global_step/sec: 5.35883
# INFO:tensorflow:loss = 0.048756186, step = 280 (3.732 sec)
# INFO:tensorflow:global_step/sec: 5.26398
# INFO:tensorflow:loss = 0.0, step = 300 (3.800 sec)
# INFO:tensorflow:global_step/sec: 5.33602
# INFO:tensorflow:loss = 0.0, step = 320 (3.747 sec)
# INFO:tensorflow:global_step/sec: 5.37716
# INFO:tensorflow:loss = 0.0, step = 340 (3.717 sec)
# INFO:tensorflow:global_step/sec: 5.48255
# INFO:tensorflow:loss = 0.0, step = 360 (3.648 sec)
# INFO:tensorflow:global_step/sec: 5.33162
# INFO:tensorflow:loss = 0.0, step = 380 (3.753 sec)
# INFO:tensorflow:global_step/sec: 5.45743
# INFO:tensorflow:loss = 0.0, step = 400 (3.663 sec)
# INFO:tensorflow:global_step/sec: 5.16904
# INFO:tensorflow:loss = 0.0, step = 420 (3.871 sec)
# INFO:tensorflow:global_step/sec: 5.49956
# INFO:tensorflow:loss = 0.0, step = 440 (3.634 sec)
# INFO:tensorflow:global_step/sec: 5.22567
# INFO:tensorflow:loss = 0.0, step = 460 (3.828 sec)
# INFO:tensorflow:global_step/sec: 5.38428
# INFO:tensorflow:loss = 0.0, step = 480 (3.716 sec)
# INFO:tensorflow:global_step/sec: 5.33728
# INFO:tensorflow:loss = 0.0, step = 500 (3.745 sec)
# INFO:tensorflow:global_step/sec: 5.37629
# INFO:tensorflow:loss = 0.0, step = 520 (3.720 sec)
# INFO:tensorflow:global_step/sec: 5.17067
# INFO:tensorflow:loss = 0.0, step = 540 (3.869 sec)
# INFO:tensorflow:global_step/sec: 5.32993
# INFO:tensorflow:loss = 0.0, step = 560 (3.753 sec)
# INFO:tensorflow:global_step/sec: 5.14427
# INFO:tensorflow:loss = 0.0, step = 580 (3.885 sec)
# INFO:tensorflow:global_step/sec: 5.14586
# INFO:tensorflow:loss = 0.0, step = 600 (3.887 sec)
# INFO:tensorflow:Saving checkpoints for 618 into /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt.
# pre-processing
# using norm
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-16-21:41:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-618
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Finished evaluation at 2019-09-16-21:41:40
# INFO:tensorflow:Saving dict for global step 618: accuracy = 0.80094784, global_step = 618, loss = 21.23691
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 618: /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-618
# INFO:tensorflow:global_step/sec: 2.25652
# INFO:tensorflow:loss = 0.0, step = 620 (8.863 sec)
# INFO:tensorflow:global_step/sec: 5.1873
# INFO:tensorflow:loss = 0.0, step = 640 (3.858 sec)
# INFO:tensorflow:global_step/sec: 5.06781
# INFO:tensorflow:loss = 0.0, step = 660 (3.946 sec)
# INFO:tensorflow:global_step/sec: 5.1599
# INFO:tensorflow:loss = 0.0, step = 680 (3.875 sec)
# INFO:tensorflow:global_step/sec: 4.74477
# INFO:tensorflow:loss = 0.0, step = 700 (4.221 sec)
# INFO:tensorflow:global_step/sec: 5.01807
# INFO:tensorflow:loss = 0.0, step = 720 (3.981 sec)
# INFO:tensorflow:global_step/sec: 4.79885
# INFO:tensorflow:loss = 0.0, step = 740 (4.170 sec)
# INFO:tensorflow:global_step/sec: 4.94355
# INFO:tensorflow:loss = 0.0, step = 760 (4.043 sec)
# INFO:tensorflow:global_step/sec: 4.74753
# INFO:tensorflow:loss = 0.0, step = 780 (4.216 sec)
# INFO:tensorflow:global_step/sec: 4.77703
# INFO:tensorflow:loss = 0.0, step = 800 (4.185 sec)
# INFO:tensorflow:global_step/sec: 4.85682
# INFO:tensorflow:loss = 0.0, step = 820 (4.117 sec)
# INFO:tensorflow:global_step/sec: 4.62461
# INFO:tensorflow:loss = 0.0, step = 840 (4.328 sec)
# INFO:tensorflow:global_step/sec: 4.70225
# INFO:tensorflow:loss = 0.0, step = 860 (4.252 sec)
# INFO:tensorflow:global_step/sec: 4.84246
# INFO:tensorflow:loss = 0.0, step = 880 (4.128 sec)
# INFO:tensorflow:global_step/sec: 4.59472
# INFO:tensorflow:loss = 0.0, step = 900 (4.355 sec)
# INFO:tensorflow:global_step/sec: 4.84607
# INFO:tensorflow:loss = 0.0, step = 920 (4.125 sec)
# INFO:tensorflow:global_step/sec: 4.67142
# INFO:tensorflow:loss = 0.0, step = 940 (4.283 sec)
# INFO:tensorflow:global_step/sec: 4.7757
# INFO:tensorflow:loss = 0.0, step = 960 (4.187 sec)
# INFO:tensorflow:global_step/sec: 4.63919
# INFO:tensorflow:loss = 0.0, step = 980 (4.312 sec)
# INFO:tensorflow:global_step/sec: 4.74335
# INFO:tensorflow:loss = 0.0, step = 1000 (4.214 sec)
# INFO:tensorflow:global_step/sec: 4.67455
# INFO:tensorflow:loss = 0.0, step = 1020 (4.280 sec)
# INFO:tensorflow:global_step/sec: 4.70132
# INFO:tensorflow:loss = 0.0, step = 1040 (4.256 sec)
# INFO:tensorflow:global_step/sec: 4.67095
# INFO:tensorflow:loss = 0.0, step = 1060 (4.279 sec)
# INFO:tensorflow:global_step/sec: 4.74023
# INFO:tensorflow:loss = 0.0, step = 1080 (4.221 sec)
# INFO:tensorflow:global_step/sec: 4.62109
# INFO:tensorflow:loss = 0.0, step = 1100 (4.330 sec)
# INFO:tensorflow:global_step/sec: 4.73331
# INFO:tensorflow:loss = 0.0, step = 1120 (4.222 sec)
# INFO:tensorflow:global_step/sec: 4.59812
# INFO:tensorflow:loss = 0.0, step = 1140 (4.350 sec)
# INFO:tensorflow:global_step/sec: 4.73384
# INFO:tensorflow:loss = 0.0, step = 1160 (4.226 sec)
# INFO:tensorflow:Saving checkpoints for 1169 into /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt.
# pre-processing
# using norm
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-16-21:43:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-1169
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Finished evaluation at 2019-09-16-21:43:39
# INFO:tensorflow:Saving dict for global step 1169: accuracy = 0.80094784, global_step = 1169, loss = 21.22082
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1169: /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-1169
# INFO:tensorflow:global_step/sec: 2.29955
# INFO:tensorflow:loss = 0.0, step = 1180 (8.695 sec)
# INFO:tensorflow:global_step/sec: 4.69001
# INFO:tensorflow:loss = 0.0, step = 1200 (4.267 sec)
# INFO:tensorflow:global_step/sec: 4.62386
# INFO:tensorflow:loss = 0.0, step = 1220 (4.325 sec)
# INFO:tensorflow:global_step/sec: 4.80266
# INFO:tensorflow:loss = 0.0, step = 1240 (4.162 sec)
# INFO:tensorflow:global_step/sec: 4.62388
# INFO:tensorflow:loss = 0.0, step = 1260 (4.326 sec)
# INFO:tensorflow:global_step/sec: 4.74286
# INFO:tensorflow:loss = 0.0, step = 1280 (4.218 sec)
# INFO:tensorflow:global_step/sec: 4.62924
# INFO:tensorflow:loss = 0.0, step = 1300 (4.318 sec)
# INFO:tensorflow:global_step/sec: 4.68306
# INFO:tensorflow:loss = 0.0, step = 1320 (4.272 sec)
# INFO:tensorflow:global_step/sec: 4.60863
# INFO:tensorflow:loss = 0.0, step = 1340 (4.342 sec)
# INFO:tensorflow:global_step/sec: 4.64361
# INFO:tensorflow:loss = 0.0, step = 1360 (4.304 sec)
# INFO:tensorflow:global_step/sec: 4.5724
# INFO:tensorflow:loss = 0.0, step = 1380 (4.377 sec)
# INFO:tensorflow:global_step/sec: 4.74619
# INFO:tensorflow:loss = 0.0, step = 1400 (4.211 sec)
# INFO:tensorflow:global_step/sec: 4.52738
# INFO:tensorflow:loss = 0.0, step = 1420 (4.419 sec)
# INFO:tensorflow:global_step/sec: 4.69091
# INFO:tensorflow:loss = 0.0, step = 1440 (4.263 sec)
# INFO:tensorflow:global_step/sec: 4.5836
# INFO:tensorflow:loss = 0.0, step = 1460 (4.364 sec)
# INFO:tensorflow:global_step/sec: 4.63224
# INFO:tensorflow:loss = 0.0, step = 1480 (4.318 sec)
# INFO:tensorflow:global_step/sec: 4.61822
# INFO:tensorflow:loss = 0.0, step = 1500 (4.330 sec)
# INFO:tensorflow:global_step/sec: 4.7324
# INFO:tensorflow:loss = 0.0, step = 1520 (4.224 sec)
# INFO:tensorflow:global_step/sec: 4.5597
# INFO:tensorflow:loss = 0.0, step = 1540 (4.387 sec)
# INFO:tensorflow:global_step/sec: 4.70631
# INFO:tensorflow:loss = 0.0, step = 1560 (4.254 sec)
# INFO:tensorflow:global_step/sec: 4.64207
# INFO:tensorflow:loss = 0.0, step = 1580 (4.304 sec)
# INFO:tensorflow:global_step/sec: 4.68194
# INFO:tensorflow:loss = 0.0, step = 1600 (4.271 sec)
# INFO:tensorflow:global_step/sec: 4.62195
# INFO:tensorflow:loss = 0.0, step = 1620 (4.329 sec)
# INFO:tensorflow:global_step/sec: 4.67564
# INFO:tensorflow:loss = 0.0, step = 1640 (4.279 sec)
# INFO:tensorflow:global_step/sec: 4.5889
# INFO:tensorflow:loss = 0.0, step = 1660 (4.356 sec)
# INFO:tensorflow:global_step/sec: 4.69584
# INFO:tensorflow:loss = 0.0, step = 1680 (4.261 sec)
# INFO:tensorflow:global_step/sec: 4.65118
# INFO:tensorflow:loss = 0.0, step = 1700 (4.298 sec)
# INFO:tensorflow:Saving checkpoints for 1707 into /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt.
# pre-processing
# using norm
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-16-21:45:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-1707
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Finished evaluation at 2019-09-16-21:45:39
# INFO:tensorflow:Saving dict for global step 1707: accuracy = 0.80094784, global_step = 1707, loss = 21.209661
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1707: /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-1707
# INFO:tensorflow:global_step/sec: 2.29494
# INFO:tensorflow:loss = 0.0, step = 1720 (8.717 sec)
# INFO:tensorflow:global_step/sec: 4.64819
# INFO:tensorflow:loss = 0.0, step = 1740 (4.302 sec)
# INFO:tensorflow:global_step/sec: 4.68223
# INFO:tensorflow:loss = 0.0, step = 1760 (4.272 sec)
# INFO:tensorflow:global_step/sec: 4.61401
# INFO:tensorflow:loss = 0.0, step = 1780 (4.333 sec)
# INFO:tensorflow:global_step/sec: 4.64217
# INFO:tensorflow:loss = 0.0, step = 1800 (4.312 sec)
# INFO:tensorflow:global_step/sec: 4.61623
# INFO:tensorflow:loss = 0.0, step = 1820 (4.331 sec)
# INFO:tensorflow:global_step/sec: 4.71212
# INFO:tensorflow:loss = 0.0, step = 1840 (4.242 sec)
# INFO:tensorflow:global_step/sec: 4.62055
# INFO:tensorflow:loss = 0.0, step = 1860 (4.330 sec)
# INFO:tensorflow:global_step/sec: 4.60205
# INFO:tensorflow:loss = 0.0, step = 1880 (4.346 sec)
# INFO:tensorflow:global_step/sec: 4.60984
# INFO:tensorflow:loss = 0.0, step = 1900 (4.336 sec)
# INFO:tensorflow:global_step/sec: 4.6264
# INFO:tensorflow:loss = 0.0, step = 1920 (4.327 sec)
# INFO:tensorflow:global_step/sec: 4.63757
# INFO:tensorflow:loss = 0.0, step = 1940 (4.308 sec)
# INFO:tensorflow:global_step/sec: 4.59419
# INFO:tensorflow:loss = 0.0, step = 1960 (4.356 sec)
# INFO:tensorflow:global_step/sec: 4.67718
# INFO:tensorflow:loss = 0.0, step = 1980 (4.275 sec)
# INFO:tensorflow:global_step/sec: 4.74951
# INFO:tensorflow:loss = 0.0, step = 2000 (4.209 sec)
# INFO:tensorflow:global_step/sec: 4.62393
# INFO:tensorflow:loss = 0.0, step = 2020 (4.326 sec)
# INFO:tensorflow:global_step/sec: 4.62877
# INFO:tensorflow:loss = 0.0, step = 2040 (4.322 sec)
# INFO:tensorflow:global_step/sec: 4.61435
# INFO:tensorflow:loss = 0.0, step = 2060 (4.335 sec)
# INFO:tensorflow:global_step/sec: 4.69107
# INFO:tensorflow:loss = 0.0, step = 2080 (4.261 sec)
# INFO:tensorflow:global_step/sec: 4.51086
# INFO:tensorflow:loss = 0.0, step = 2100 (4.437 sec)
# INFO:tensorflow:global_step/sec: 4.81119
# INFO:tensorflow:loss = 0.0, step = 2120 (4.154 sec)
# INFO:tensorflow:global_step/sec: 4.65007
# INFO:tensorflow:loss = 0.0, step = 2140 (4.301 sec)
# INFO:tensorflow:global_step/sec: 4.70421
# INFO:tensorflow:loss = 0.0, step = 2160 (4.253 sec)
# INFO:tensorflow:global_step/sec: 4.64693
# INFO:tensorflow:loss = 0.0, step = 2180 (4.303 sec)
# INFO:tensorflow:global_step/sec: 4.7874
# INFO:tensorflow:loss = 0.0, step = 2200 (4.178 sec)
# INFO:tensorflow:global_step/sec: 4.5094
# INFO:tensorflow:loss = 0.0, step = 2220 (4.438 sec)
# INFO:tensorflow:global_step/sec: 4.71461
# INFO:tensorflow:loss = 0.0, step = 2240 (4.239 sec)
# INFO:tensorflow:Saving checkpoints for 2245 into /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt.
# pre-processing
# using norm
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-16-21:47:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-2245
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Finished evaluation at 2019-09-16-21:47:40
# INFO:tensorflow:Saving dict for global step 2245: accuracy = 0.80094784, global_step = 2245, loss = 21.200975
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2245: /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-2245
# INFO:tensorflow:global_step/sec: 2.29452
# INFO:tensorflow:loss = 0.0, step = 2260 (8.717 sec)
# INFO:tensorflow:global_step/sec: 4.71596
# INFO:tensorflow:loss = 0.0, step = 2280 (4.242 sec)
# INFO:tensorflow:global_step/sec: 4.68391
# INFO:tensorflow:loss = 0.0, step = 2300 (4.268 sec)
# INFO:tensorflow:global_step/sec: 4.73097
# INFO:tensorflow:loss = 0.0, step = 2320 (4.227 sec)
# INFO:tensorflow:global_step/sec: 4.64243
# INFO:tensorflow:loss = 0.0, step = 2340 (4.309 sec)
# INFO:tensorflow:global_step/sec: 4.53429
# INFO:tensorflow:loss = 0.0, step = 2360 (4.412 sec)
# INFO:tensorflow:global_step/sec: 4.63346
# INFO:tensorflow:loss = 0.0, step = 2380 (4.314 sec)
# INFO:tensorflow:global_step/sec: 4.71777
# INFO:tensorflow:loss = 0.0, step = 2400 (4.241 sec)
# INFO:tensorflow:global_step/sec: 4.60338
# INFO:tensorflow:loss = 0.0, step = 2420 (4.346 sec)
# INFO:tensorflow:global_step/sec: 4.71314
# INFO:tensorflow:loss = 0.0, step = 2440 (4.241 sec)
# INFO:tensorflow:global_step/sec: 4.6372
# INFO:tensorflow:loss = 0.0, step = 2460 (4.315 sec)
# INFO:tensorflow:global_step/sec: 4.71949
# INFO:tensorflow:loss = 0.0, step = 2480 (4.236 sec)
# INFO:tensorflow:global_step/sec: 4.34442
# INFO:tensorflow:loss = 0.0, step = 2500 (4.606 sec)
# INFO:tensorflow:global_step/sec: 4.69504
# INFO:tensorflow:loss = 0.0, step = 2520 (4.258 sec)
# INFO:tensorflow:global_step/sec: 4.68405
# INFO:tensorflow:loss = 0.0, step = 2540 (4.269 sec)
# INFO:tensorflow:global_step/sec: 4.72357
# INFO:tensorflow:loss = 0.0, step = 2560 (4.234 sec)
# INFO:tensorflow:global_step/sec: 4.62848
# INFO:tensorflow:loss = 0.0, step = 2580 (4.322 sec)
# INFO:tensorflow:global_step/sec: 4.73026
# INFO:tensorflow:loss = 0.0, step = 2600 (4.227 sec)
# INFO:tensorflow:global_step/sec: 4.62401
# INFO:tensorflow:loss = 0.0, step = 2620 (4.325 sec)
# INFO:tensorflow:global_step/sec: 4.63905
# INFO:tensorflow:loss = 0.0, step = 2640 (4.315 sec)
# INFO:tensorflow:global_step/sec: 4.64887
# INFO:tensorflow:loss = 0.0, step = 2660 (4.298 sec)
# INFO:tensorflow:global_step/sec: 4.70373
# INFO:tensorflow:loss = 0.0, step = 2680 (4.252 sec)
# INFO:tensorflow:global_step/sec: 4.64009
# INFO:tensorflow:loss = 0.0, step = 2700 (4.311 sec)
# INFO:tensorflow:global_step/sec: 4.76789
# INFO:tensorflow:loss = 0.0, step = 2720 (4.194 sec)
# INFO:tensorflow:global_step/sec: 4.61858
# INFO:tensorflow:loss = 0.0, step = 2740 (4.331 sec)
# INFO:tensorflow:global_step/sec: 4.65377
# INFO:tensorflow:loss = 0.0, step = 2760 (4.298 sec)
# INFO:tensorflow:global_step/sec: 4.71159
# INFO:tensorflow:loss = 0.0, step = 2780 (4.247 sec)
# INFO:tensorflow:Saving checkpoints for 2784 into /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt.
# pre-processing
# using norm
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-16-21:49:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-2784
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Finished evaluation at 2019-09-16-21:49:40
# INFO:tensorflow:Saving dict for global step 2784: accuracy = 0.80094784, global_step = 2784, loss = 21.19343
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2784: /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-2784
# INFO:tensorflow:global_step/sec: 2.31973
# INFO:tensorflow:loss = 0.0, step = 2800 (8.619 sec)
# INFO:tensorflow:global_step/sec: 4.6509
# INFO:tensorflow:loss = 0.0, step = 2820 (4.301 sec)
# INFO:tensorflow:global_step/sec: 4.79449
# INFO:tensorflow:loss = 0.0, step = 2840 (4.171 sec)
# INFO:tensorflow:global_step/sec: 4.6399
# INFO:tensorflow:loss = 0.0, step = 2860 (4.310 sec)
# INFO:tensorflow:global_step/sec: 4.72858
# INFO:tensorflow:loss = 0.0, step = 2880 (4.230 sec)
# INFO:tensorflow:global_step/sec: 4.59001
# INFO:tensorflow:loss = 0.0, step = 2900 (4.359 sec)
# INFO:tensorflow:global_step/sec: 4.72692
# INFO:tensorflow:loss = 0.0, step = 2920 (4.230 sec)
# INFO:tensorflow:global_step/sec: 4.64526
# INFO:tensorflow:loss = 0.0, step = 2940 (4.306 sec)
# INFO:tensorflow:global_step/sec: 4.6854
# INFO:tensorflow:loss = 0.0, step = 2960 (4.270 sec)
# INFO:tensorflow:global_step/sec: 4.63873
# INFO:tensorflow:loss = 0.0, step = 2980 (4.310 sec)
# INFO:tensorflow:global_step/sec: 4.70998
# INFO:tensorflow:loss = 0.0, step = 3000 (4.247 sec)
# INFO:tensorflow:global_step/sec: 4.60284
# INFO:tensorflow:loss = 0.0, step = 3020 (4.346 sec)
# INFO:tensorflow:global_step/sec: 4.7092
# INFO:tensorflow:loss = 0.0, step = 3040 (4.245 sec)
# INFO:tensorflow:global_step/sec: 4.63029
# INFO:tensorflow:loss = 0.0, step = 3060 (4.320 sec)
# INFO:tensorflow:global_step/sec: 4.67046
# INFO:tensorflow:loss = 0.0, step = 3080 (4.281 sec)
# INFO:tensorflow:global_step/sec: 4.61693
# INFO:tensorflow:loss = 0.0, step = 3100 (4.334 sec)
# INFO:tensorflow:global_step/sec: 4.7024
# INFO:tensorflow:loss = 0.0, step = 3120 (4.253 sec)
# INFO:tensorflow:global_step/sec: 4.65345
# INFO:tensorflow:loss = 0.0, step = 3140 (4.296 sec)
# INFO:tensorflow:global_step/sec: 4.62654
# INFO:tensorflow:loss = 0.0, step = 3160 (4.323 sec)
# INFO:tensorflow:global_step/sec: 4.65316
# INFO:tensorflow:loss = 0.0, step = 3180 (4.301 sec)
# INFO:tensorflow:global_step/sec: 4.73774
# INFO:tensorflow:loss = 0.0, step = 3200 (4.217 sec)
# INFO:tensorflow:global_step/sec: 4.56745
# INFO:tensorflow:loss = 0.0, step = 3220 (4.382 sec)
# INFO:tensorflow:global_step/sec: 4.69522
# INFO:tensorflow:loss = 0.0, step = 3240 (4.258 sec)
# INFO:tensorflow:global_step/sec: 4.64866
# INFO:tensorflow:loss = 0.0, step = 3260 (4.301 sec)
# INFO:tensorflow:global_step/sec: 4.77205
# INFO:tensorflow:loss = 0.0, step = 3280 (4.191 sec)
# INFO:tensorflow:global_step/sec: 4.55078
# INFO:tensorflow:loss = 0.0, step = 3300 (4.399 sec)
# INFO:tensorflow:global_step/sec: 4.7668
# INFO:tensorflow:loss = 0.0, step = 3320 (4.192 sec)
# INFO:tensorflow:Saving checkpoints for 3325 into /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt.
# pre-processing
# using norm
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-16-21:51:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-3325
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Finished evaluation at 2019-09-16-21:51:40
# INFO:tensorflow:Saving dict for global step 3325: accuracy = 0.80094784, global_step = 3325, loss = 21.18671
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3325: /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-3325
# INFO:tensorflow:global_step/sec: 2.29734
# INFO:tensorflow:loss = 0.0, step = 3340 (8.706 sec)
# INFO:tensorflow:global_step/sec: 4.73675
# INFO:tensorflow:loss = 0.0, step = 3360 (4.223 sec)
# INFO:tensorflow:global_step/sec: 4.7304
# INFO:tensorflow:loss = 0.0, step = 3380 (4.227 sec)
# INFO:tensorflow:global_step/sec: 4.72094
# INFO:tensorflow:loss = 0.0, step = 3400 (4.237 sec)
# INFO:tensorflow:global_step/sec: 4.64428
# INFO:tensorflow:loss = 0.0, step = 3420 (4.307 sec)
# INFO:tensorflow:global_step/sec: 4.75074
# INFO:tensorflow:loss = 0.0, step = 3440 (4.209 sec)
# INFO:tensorflow:global_step/sec: 4.66569
# INFO:tensorflow:loss = 0.0, step = 3460 (4.287 sec)
# INFO:tensorflow:global_step/sec: 4.68565
# INFO:tensorflow:loss = 0.0, step = 3480 (4.269 sec)
# INFO:tensorflow:global_step/sec: 4.66428
# INFO:tensorflow:loss = 0.0, step = 3500 (4.289 sec)
# INFO:tensorflow:global_step/sec: 4.73041
# INFO:tensorflow:loss = 0.0, step = 3520 (4.226 sec)
# INFO:tensorflow:global_step/sec: 4.6332
# INFO:tensorflow:loss = 0.0, step = 3540 (4.317 sec)
# INFO:tensorflow:global_step/sec: 4.75397
# INFO:tensorflow:loss = 0.0, step = 3560 (4.207 sec)
# INFO:tensorflow:global_step/sec: 4.60433
# INFO:tensorflow:loss = 0.0, step = 3580 (4.344 sec)
# INFO:tensorflow:global_step/sec: 4.67455
# INFO:tensorflow:loss = 0.0, step = 3600 (4.281 sec)
# INFO:tensorflow:global_step/sec: 4.67907
# INFO:tensorflow:loss = 0.0, step = 3620 (4.272 sec)
# INFO:tensorflow:global_step/sec: 4.72791
# INFO:tensorflow:loss = 0.0, step = 3640 (4.229 sec)
# INFO:tensorflow:global_step/sec: 4.64871
# INFO:tensorflow:loss = 0.0, step = 3660 (4.304 sec)
# INFO:tensorflow:global_step/sec: 4.77254
# INFO:tensorflow:loss = 0.0, step = 3680 (4.189 sec)
# INFO:tensorflow:global_step/sec: 4.63579
# INFO:tensorflow:loss = 0.0, step = 3700 (4.315 sec)
# INFO:tensorflow:global_step/sec: 4.66124
# INFO:tensorflow:loss = 0.0, step = 3720 (4.295 sec)
# INFO:tensorflow:global_step/sec: 4.66471
# INFO:tensorflow:loss = 0.0, step = 3740 (4.283 sec)
# INFO:tensorflow:global_step/sec: 4.87168
# INFO:tensorflow:loss = 0.0, step = 3760 (4.105 sec)
# INFO:tensorflow:global_step/sec: 4.64404
# INFO:tensorflow:loss = 0.0, step = 3780 (4.308 sec)
# INFO:tensorflow:global_step/sec: 4.77394
# INFO:tensorflow:loss = 0.0, step = 3800 (4.188 sec)
# INFO:tensorflow:global_step/sec: 4.64615
# INFO:tensorflow:loss = 0.0, step = 3820 (4.305 sec)
# INFO:tensorflow:global_step/sec: 4.6872
# INFO:tensorflow:loss = 0.0, step = 3840 (4.268 sec)
# INFO:tensorflow:global_step/sec: 4.62321
# INFO:tensorflow:loss = 0.0, step = 3860 (4.325 sec)
# INFO:tensorflow:Saving checkpoints for 3868 into /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt.
# pre-processing
# using norm
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-16-21:53:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-3868
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Finished evaluation at 2019-09-16-21:53:40
# INFO:tensorflow:Saving dict for global step 3868: accuracy = 0.80094784, global_step = 3868, loss = 21.180437
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3868: /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-3868
# INFO:tensorflow:global_step/sec: 2.33237
# INFO:tensorflow:loss = 0.0, step = 3880 (8.575 sec)
# INFO:tensorflow:global_step/sec: 4.62811
# INFO:tensorflow:loss = 0.0, step = 3900 (4.323 sec)
# INFO:tensorflow:global_step/sec: 4.7562
# INFO:tensorflow:loss = 0.0, step = 3920 (4.206 sec)
# INFO:tensorflow:global_step/sec: 4.72275
# INFO:tensorflow:loss = 0.0, step = 3940 (4.233 sec)
# INFO:tensorflow:global_step/sec: 4.70903
# INFO:tensorflow:loss = 0.0, step = 3960 (4.247 sec)
# INFO:tensorflow:global_step/sec: 4.58738
# INFO:tensorflow:loss = 0.0, step = 3980 (4.361 sec)
# INFO:tensorflow:global_step/sec: 4.72181
# INFO:tensorflow:loss = 0.0, step = 4000 (4.234 sec)
# INFO:tensorflow:global_step/sec: 4.57156
# INFO:tensorflow:loss = 0.0, step = 4020 (4.378 sec)
# INFO:tensorflow:global_step/sec: 4.75083
# INFO:tensorflow:loss = 0.0, step = 4040 (4.207 sec)
# INFO:tensorflow:global_step/sec: 4.62042
# INFO:tensorflow:loss = 0.0, step = 4060 (4.328 sec)
# INFO:tensorflow:global_step/sec: 4.69965
# INFO:tensorflow:loss = 0.0, step = 4080 (4.259 sec)
# INFO:tensorflow:global_step/sec: 4.70463
# INFO:tensorflow:loss = 0.0, step = 4100 (4.248 sec)
# INFO:tensorflow:global_step/sec: 4.70432
# INFO:tensorflow:loss = 0.0, step = 4120 (4.251 sec)
# INFO:tensorflow:global_step/sec: 4.57516
# INFO:tensorflow:loss = 0.0, step = 4140 (4.373 sec)
# INFO:tensorflow:global_step/sec: 4.73809
# INFO:tensorflow:loss = 0.0, step = 4160 (4.222 sec)
# INFO:tensorflow:global_step/sec: 4.62163
# INFO:tensorflow:loss = 0.0, step = 4180 (4.326 sec)
# INFO:tensorflow:global_step/sec: 4.69629
# INFO:tensorflow:loss = 0.0, step = 4200 (4.260 sec)
# INFO:tensorflow:global_step/sec: 4.60435
# INFO:tensorflow:loss = 0.0, step = 4220 (4.343 sec)
# INFO:tensorflow:global_step/sec: 4.72
# INFO:tensorflow:loss = 0.0, step = 4240 (4.238 sec)
# INFO:tensorflow:global_step/sec: 4.62779
# INFO:tensorflow:loss = 0.0, step = 4260 (4.322 sec)
# INFO:tensorflow:global_step/sec: 4.8037
# INFO:tensorflow:loss = 0.0, step = 4280 (4.163 sec)
# INFO:tensorflow:global_step/sec: 4.64354
# INFO:tensorflow:loss = 0.0, step = 4300 (4.306 sec)
# INFO:tensorflow:global_step/sec: 4.70152
# INFO:tensorflow:loss = 0.0, step = 4320 (4.255 sec)
# INFO:tensorflow:global_step/sec: 4.6718
# INFO:tensorflow:loss = 0.0, step = 4340 (4.280 sec)
# INFO:tensorflow:global_step/sec: 4.67235
# INFO:tensorflow:loss = 0.0, step = 4360 (4.280 sec)
# INFO:tensorflow:global_step/sec: 4.57658
# INFO:tensorflow:loss = 0.0, step = 4380 (4.373 sec)
# INFO:tensorflow:global_step/sec: 4.74092
# INFO:tensorflow:loss = 0.0, step = 4400 (4.216 sec)
# INFO:tensorflow:Saving checkpoints for 4409 into /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt.
# pre-processing
# using norm
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-16-21:55:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-4409
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Finished evaluation at 2019-09-16-21:55:40
# INFO:tensorflow:Saving dict for global step 4409: accuracy = 0.80094784, global_step = 4409, loss = 21.174723
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4409: /data/jma/model/resnet4_experiment/kernel5_filter8_snnl0.0/model.ckpt-4409
# INFO:tensorflow:global_step/sec: 2.24137
# INFO:tensorflow:loss = 0.0, step = 4420 (8.922 sec)
# INFO:tensorflow:global_step/sec: 4.76808
# INFO:tensorflow:loss = 0.0, step = 4440 (4.196 sec)
# INFO:tensorflow:global_step/sec: 4.69316
# INFO:tensorflow:loss = 0.0, step = 4460 (4.260 sec)
# INFO:tensorflow:global_step/sec: 4.76312
# INFO:tensorflow:loss = 0.0, step = 4480 (4.199 sec)
# INFO:tensorflow:global_step/sec: 4.6103
# INFO:tensorflow:loss = 0.0, step = 4500 (4.339 sec)
# INFO:tensorflow:global_step/sec: 4.71584
# INFO:tensorflow:loss = 0.0, step = 4520 (4.243 sec)
# INFO:tensorflow:global_step/sec: 4.75185
# INFO:tensorflow:loss = 0.0, step = 4540 (4.206 sec)
# INFO:tensorflow:global_step/sec: 4.71117
# INFO:tensorflow:loss = 0.0, step = 4560 (4.246 sec)
# INFO:tensorflow:global_step/sec: 4.67403
# INFO:tensorflow:loss = 0.0, step = 4580 (4.278 sec)
# INFO:tensorflow:global_step/sec: 4.70359
# INFO:tensorflow:loss = 0.0, step = 4600 (4.253 sec)
# INFO:tensorflow:global_step/sec: 4.62448
# INFO:tensorflow:loss = 0.0, step = 4620 (4.325 sec)
# INFO:tensorflow:global_step/sec: 4.68079
# INFO:tensorflow:loss = 0.0, step = 4640 (4.275 sec)
# INFO:tensorflow:global_step/sec: 4.63505
# INFO:tensorflow:loss = 0.0, step = 4660 (4.312 sec)
# INFO:tensorflow:global_step/sec: 4.78412
# INFO:tensorflow:loss = 0.0, step = 4680 (4.181 sec)
# INFO:tensorflow:global_step/sec: 4.59052
# INFO:tensorflow:loss = 0.0, step = 4700 (4.358 sec)
# INFO:tensorflow:global_step/sec: 4.72951
# INFO:tensorflow:loss = 0.0, step = 4720 (4.227 sec)
# INFO:tensorflow:global_step/sec: 4.64586
# INFO:tensorflow:loss = 0.0, step = 4740 (4.306 sec)
# INFO:tensorflow:global_step/sec: 4.73529
# INFO:tensorflow:loss = 0.0, step = 4760 (4.223 sec)
# INFO:tensorflow:global_step/sec: 4.64702
# INFO:tensorflow:loss = 0.0, step = 4780 (4.304 sec)
# INFO:tensorflow:global_step/sec: 4.74027
# INFO:tensorflow:loss = 0.0, step = 4800 (4.221 sec)
# INFO:tensorflow:global_step/sec: 4.68778
# INFO:tensorflow:loss = 0.0, step = 4820 (4.265 sec)
# INFO:tensorflow:global_step/sec: 4.70823
# INFO:tensorflow:loss = 0.0, step = 4840 (4.248 sec)
# INFO:tensorflow:global_step/sec: 4.5852
# INFO:tensorflow:loss = 0.0, step = 4860 (4.365 sec)
# INFO:tensorflow:global_step/sec: 4.73895
# INFO:tensorflow:loss = 0.0, step = 4880 (4.218 sec)
# INFO:tensorflow:global_step/sec: 4.59632
# INFO:tensorflow:loss = 0.0, step = 4900 (4.351 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ea0f5608de64> in <module>()
#      58             eval_spec = tf.estimator.EvalSpec(input_fn=eval_input_fn, throttle_secs=120)
#      59
# ---> 60             tf.estimator.train_and_evaluate(model, train_spec, eval_spec)
#      61
#      62
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/training.py in train_and_evaluate(estimator, train_spec, eval_spec)
#     469         '(with task id 0).  Given task id {}'.format(config.task_id))
#     470
# --> 471   return executor.run()
#     472
#     473
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/training.py in run(self)
#     608         config.task_type != run_config_lib.TaskType.EVALUATOR):
#     609       logging.info('Running training and evaluation locally (non-distributed).')
# --> 610       return self.run_local()
#     611
#     612     # Distributed case.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/training.py in run_local(self)
#     709         max_steps=self._train_spec.max_steps,
#     710         hooks=train_hooks,
# --> 711         saving_listeners=saving_listeners)
#     712
#     713     eval_result = listener_for_eval.eval_result or _EvalResult(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     354
#     355       saving_listeners = _check_listeners_type(saving_listeners)
# --> 356       loss = self._train_model(input_fn, hooks, saving_listeners)
#     357       logging.info('Loss for final step: %s.', loss)
#     358       return self
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1179       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1180     else:
# -> 1181       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1182
#    1183   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1213       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1214                                              hooks, global_step_tensor,
# -> 1215                                              saving_listeners)
#    1216
#    1217   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1407       loss = None
#    1408       while not mon_sess.should_stop():
# -> 1409         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1410     return loss
#    1411
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     669                           feed_dict=feed_dict,
#     670                           options=options,
# --> 671                           run_metadata=run_metadata)
#     672
#     673   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1146                               feed_dict=feed_dict,
#    1147                               options=options,
# -> 1148                               run_metadata=run_metadata)
#    1149       except _PREEMPTION_ERRORS as e:
#    1150         logging.info('An error was raised. This may be due to a preemption in '
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1222   def run(self, *args, **kwargs):
#    1223     try:
# -> 1224       return self._sess.run(*args, **kwargs)
#    1225     except _PREEMPTION_ERRORS:
#    1226       raise
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1294                                   feed_dict=feed_dict,
#    1295                                   options=options,
# -> 1296                                   run_metadata=run_metadata)
#    1297
#    1298     for hook in self._hooks:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1074
#    1075   def run(self, *args, **kwargs):
# -> 1076     return self._sess.run(*args, **kwargs)
#    1077
#    1078   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     885     try:
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#     889         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1108     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#    1112       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1284     if handle is None:
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#    1288       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1290   def _do_call(self, fn, *args):
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#    1294       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1275       self._extend_graph()
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#    1279     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1365     return tf_session.TF_SessionRun_wrapper(
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#    1369   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Experimentation

# %% [markdown]
# ## Evaluation

# %%
tf.logging.set_verbosity(tf.logging.INFO)

b_size = 32

learning_rate = 0.005

random_seed = 777

num_steps = 20000

resnet10_checkpoint_path_base = "/data/jma/model/relabeled_data/resnet10/no_augment_255_norm/"

# kernel_sizes = [7, 9, 10, 11, 13]
# filter_sizes = [10]
# snnl_weights = [0.0]

kernel_sizes = [5]
filter_sizes = [8]
snnl_weights = [0.0]

data_root = "./data/custom_activation_map_data/"

image_paths = load_image_paths(data_root)
train_paths, eval_paths, test_paths = split(image_paths, seed=random_seed)


eval_input_fn = lambda : load(data_root, image_paths, training=False, augment=False, batch_size=1, shuffle=False)


for filter_size in filter_sizes:
    for kernel_size in kernel_sizes:
        
        for snnl_weight in snnl_weights:
            tf.summary.FileWriterCache.clear()
 
            model_path = resnet10_checkpoint_path_base + "kernel" + str(kernel_size) + "_filter" + str(filter_size) + "_snnl" + str(snnl_weight)+"/"
            print(model_path)

            model_fn = lambda features, labels, mode: resnet10_model_fn(features, labels, mode, 
                                                                        conv_kernel=kernel_size, 
                                                                        num_channels=filter_size,
                                                                        snnl_weight=snnl_weight,
                                                                        log=True)

            model = tf.estimator.Estimator(model_fn=model_fn, model_dir=model_path)

            model.evaluate(eval_input_fn)
# Out:
# /data/jma/model/relabeled_data/resnet10/no_augment_255_norm/kernel5_filter8_snnl0.0/
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/data/jma/model/relabeled_data/resnet10/no_augment_255_norm/kernel5_filter8_snnl0.0/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3f4c782128>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# in gpu part
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-01-05:35:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jma/model/relabeled_data/resnet10/no_augment_255_norm/kernel5_filter8_snnl0.0/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-08-01-05:35:49
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.5, global_step = 10000, loss = 13.577061
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: /data/jma/model/relabeled_data/resnet10/no_augment_255_norm/kernel5_filter8_snnl0.0/model.ckpt-10000

# %% [markdown]
# # Metrics

# %% [markdown]
# ## Metric Utility Functions

# %%
def path_to_label(paths, data_root):

    data_root = pathlib.Path(data_root)

    # return label names
    label_names = sorted(item.name for item in data_root.glob('*/') if item.is_dir())

    # assign index to label
    label_to_index = dict((name, index) for index,name in enumerate(label_names))

    # array of all labels corresponding to image_paths
    all_image_labels = [label_to_index[pathlib.Path(path).parent.name]
                        for path in paths]
    
    return all_image_labels

print(eval_paths[:20])
# Out:
# ['data/data_relabeled_png/1/IM-0012-0005-0001.dcm.png', 'data/data_relabeled_png/1/IM-0069-0023-0001.dcm.png', 'data/data_relabeled_png/1/IM-0046-0027-0001.dcm.png', 'data/data_relabeled_png/1/IM-0064-0014-0001.dcm.png', 'data/data_relabeled_png/2/IM-0054-0018-0001.dcm.png', 'data/data_relabeled_png/1/IM-0068-0022-0001.dcm.png', 'data/data_relabeled_png/1/IM-0053-0026-0001.dcm.png', 'data/data_relabeled_png/1/IM-0050-0004-0001.dcm.png', 'data/data_relabeled_png/1/IM-0003-0001-0001.dcm.png', 'data/data_relabeled_png/2/IM-0016-0001-0001.dcm.png', 'data/data_relabeled_png/1/IM-0071-0022-0001.dcm.png', 'data/data_relabeled_png/1/IM-0042-0009-0001.dcm.png', 'data/data_relabeled_png/2/IM-0005-0018-0001.dcm.png', 'data/data_relabeled_png/1/IM-0032-0031-0001.dcm.png', 'data/data_relabeled_png/0/IM-0004-0004-0001.dcm.png', 'data/data_relabeled_png/1/IM-0054-0006-0001.dcm.png', 'data/data_relabeled_png/1/IM-0031-0016-0001.dcm.png', 'data/data_relabeled_png/1/IM-0047-0024-0001.dcm.png', 'data/data_relabeled_png/1/IM-0003-0026-0001.dcm.png', 'data/data_relabeled_png/1/IM-0018-0004-0001.dcm.png']

# %% [markdown]
# ## Confusion Matrices

# %%
# %matplotlib inline

tf.logging.set_verbosity(tf.logging.ERROR)

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

resnet10_checkpoint_path_base = "/data/jma/model/relabeled_data/resnet4/"

kernel_sizes = [3,5]
filter_sizes = [4,8]
snnl_weights = [0.00]

data_path = "./data/data_relabeled_png/"

random_seed = 777

image_paths = load_data_util.load_image_paths(data_path)
train_paths, eval_paths, test_paths = load_data_util.split(image_paths, seed=random_seed)



eval_input_fn = lambda : load_data_util.load(data_path, eval_paths, training=False, augment=False, shuffle=False, batch_size=64)


for filter_size in filter_sizes:
    for kernel_size in kernel_sizes:
        
        for snnl_weight in snnl_weights:
            tf.summary.FileWriterCache.clear()

            title = "kernel" + str(kernel_size) + "_filter" + str(filter_size) + "_snnl" + str(snnl_weight)
            
            model_path = resnet10_checkpoint_path_base + title +"/"
            print(model_path)
        
        
            model_fn = lambda features, labels, mode: resnet4_model_fn(features, labels, mode, 
                                                                        conv_kernel=kernel_size, 
                                                                        num_channels=filter_size)
            model = tf.estimator.Estimator(model_fn=model_fn, model_dir=model_path)

            values = model.predict(eval_input_fn)


            original_labels = path_to_label(eval_paths, data_path)
            predicted_labels = list(values)

            cm = tf.confusion_matrix(original_labels, predicted_labels)
            cm = tf.to_float(cm)

            cm = cm.numpy()
            
            row_sums = cm.sum(axis=1)
            cm = cm / row_sums[:, np.newaxis]
            
            df_cm = pd.DataFrame(cm, range(3), range(3))
            #plt.figure(figsize = (10,7))

            sns.set(font_scale=1)#for label size
            plt.suptitle("kernel" + str(kernel_size) + "_filter" + str(filter_size))
            ax = sns.heatmap(df_cm, annot=True,annot_kws={"size": 16})# font size
            ax.set(xlabel='predicted', ylabel='true')
            plt.show()
# Out:
# /data/jma/model/relabeled_data/resnet4/kernel3_filter4_snnl0.0/
# in gpu part
# /data/jma/model/relabeled_data/resnet4/kernel5_filter4_snnl0.0/
# in gpu part
# /data/jma/model/relabeled_data/resnet4/kernel3_filter8_snnl0.0/
# in gpu part
# /data/jma/model/relabeled_data/resnet4/kernel5_filter8_snnl0.0/
# in gpu part

# %% [markdown]
# ## Incorrectly Classified Images (PNG Format)

# %%
# %matplotlib inline

tf.logging.set_verbosity(tf.logging.ERROR)

import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

resnet10_checkpoint_path_base = "/data/jma/model/relabeled_data/resnet4/"

data_path = "./data/data_relabeled_png//"

image_paths = load_image_paths(data_path)
train_paths, eval_paths, test_paths = split(image_paths, seed=random_seed)


train_input_fn = lambda : load(data_path, train_paths, training=True)
eval_input_fn = lambda : load(data_path, eval_paths, training=False)
test_input_fn = lambda : load(data_path, test_paths, training=False)

# change these======
working_paths = eval_paths
working_input_fn = eval_input_fn

kernel_size=5
filter_size=8
snnl_weight=0.0
#=========

model_path = resnet10_checkpoint_path_base + "kernel" + str(kernel_size) + "_filter" + str(filter_size) + "_snnl" + str(snnl_weight) + "/"
print(model_path)

model_fn = lambda features, labels, mode: resnet4_model_fn(features, labels, mode, 
                                                            conv_kernel=kernel_size, 
                                                            num_channels=filter_size)
model = tf.estimator.Estimator(model_fn=model_fn, model_dir=model_path)

values = model.predict(working_input_fn)

original_labels = path_to_label(working_paths, data_path)
predicted_labels = list(values)

# make a plot?

for index in range(len(working_paths)):
    if original_labels[index] != predicted_labels[index]:
        # add image to plot

        img = Image.open(working_paths[index])
        
        basewidth = 256

        wpercent = (basewidth/float(img.size[0]))
        hsize = int((float(img.size[1])*float(wpercent)))
        img = img.resize((basewidth,hsize), Image.ANTIALIAS)

        
        d = ImageDraw.Draw(img)
        
        # debug this shit
        d.text((10,10), "True: " + str(original_labels[index]) + 
               ", Pred: " + str(predicted_labels[index]), 
               fill="white", font=ImageFont.truetype("./fonts/arial-bold.ttf", 15))       
                
        display(img)
# Out:
# /data/jma/model/relabeled_data/resnet4/kernel5_filter8_snnl0.0/
# in gpu part
# <PIL.Image.Image image mode=L size=256x256 at 0x7F3E6500FF98>
